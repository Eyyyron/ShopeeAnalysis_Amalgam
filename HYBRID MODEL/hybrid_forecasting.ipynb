# %%
# ============================================================
# HYBRID SARIMA-LSTM: Seasonal Demand Forecasting (Per Category)
# Dataset: consolidated_file_cleaned_v2.csv
# ============================================================

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
from tensorflow.keras.callbacks import EarlyStopping

# -----------------------------
# 1. Load dataset
# -----------------------------
FILE = "consolidated_file_cleaned_v2.csv"
df = pd.read_csv(FILE)

# Clean and prepare
df['time'] = pd.to_datetime(df['time'])
df = df.sort_values(by='time')
df = df[df['suitable_for_seasonal_analysis'] == True]

# Focus on monthly demand column
df['month'] = df['time'].dt.to_period('M').dt.to_timestamp()
category_data = df.groupby(['month','second-level_category'])['sold/m'].sum().reset_index()

# -----------------------------
# 2. SARIMA fitting helper
# -----------------------------
def safe_sarima_fit(ts):
    """Attempt SARIMA fitting with fallback parameters."""
    sarima_orders = [
        ((1,1,1), (1,1,1,12)),
        ((0,1,1), (1,1,1,12)),
        ((1,1,0), (0,1,1,12)),
        ((0,1,1), (0,1,1,12)),
        ((1,0,0), (1,0,0,12))
    ]
    for order, sorder in sarima_orders:
        try:
            model = SARIMAX(
                ts,
                order=order,
                seasonal_order=sorder,
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            fitted = model.fit(disp=False)
            return fitted
        except Exception:
            continue
    return None

# -----------------------------
# 3. Hybrid SARIMA + LSTM
# -----------------------------
hybrid_results = []
FORECAST_STEPS = 12  # forecast 12 months ahead

for cat in category_data['second-level_category'].unique():
    print(f"\nProcessing Category: {cat}")

    data_cat = category_data[category_data['second-level_category'] == cat]
    ts = data_cat.set_index('month')['sold/m']

    # Skip categories with insufficient variation
    if len(ts) < 18 or ts.sum() == 0 or ts.nunique() == 1:
        print(f"Skipping {cat}: not enough data or variation")
        continue

    # -----------------------------
    # SARIMA Model
    # -----------------------------
    sarima_fit = safe_sarima_fit(ts)
    if sarima_fit is None:
        print(f"⚠️ Skipping {cat}: SARIMA could not fit")
        continue

    sarima_forecast = sarima_fit.forecast(steps=FORECAST_STEPS)
    residuals = sarima_fit.resid

    # -----------------------------
    # LSTM on residuals
    # -----------------------------
    scaler = MinMaxScaler()
    scaled_res = scaler.fit_transform(residuals.values.reshape(-1,1))

    X, y = [], []
    for i in range(12, len(scaled_res)):
        X.append(scaled_res[i-12:i])
        y.append(scaled_res[i])
    X, y = np.array(X), np.array(y)

    lstm_model = Sequential([
        Input(shape=(X.shape[1], 1)),
        LSTM(32, activation='tanh', return_sequences=True),
        LSTM(16, activation='tanh'),
        Dense(1)
    ])
    lstm_model.compile(optimizer='adam', loss='mse')

    es = EarlyStopping(monitor='loss', patience=10, restore_best_weights=True)
    lstm_model.fit(X, y, epochs=50, batch_size=8, verbose=0, callbacks=[es])

    # Predict future residuals
    last_sequence = scaled_res[-12:]
    residual_preds = []
    seq = last_sequence.copy()
    for _ in range(FORECAST_STEPS):
        inp = seq.reshape(1, 12, 1)
        pred = lstm_model.predict(inp, verbose=0)
        residual_preds.append(pred[0][0])
        seq = np.roll(seq, -1)
        seq[-1] = pred

    residual_forecast = scaler.inverse_transform(np.array(residual_preds).reshape(-1,1)).flatten()

    # -----------------------------
    # Hybrid forecast = SARIMA + LSTM residuals
    # -----------------------------
    hybrid_forecast = sarima_forecast.values + residual_forecast

    forecast_dates = pd.date_range(start=ts.index.max() + pd.offsets.MonthBegin(), 
                                   periods=FORECAST_STEPS, freq='MS')

    for d, f in zip(forecast_dates, hybrid_forecast):
        hybrid_results.append({
            'category': cat,
            'forecast_date': d,
            'predicted_sold_per_month': round(max(f,0),2)
        })

# -----------------------------
# 4. Save to CSV
# -----------------------------
hybrid_df = pd.DataFrame(hybrid_results)
hybrid_df.to_csv("hybrid_sarima_lstm_forecasts.csv", index=False)
print("\n✅ Hybrid forecasts saved to: hybrid_sarima_lstm_forecasts.csv")
hybrid_df.head()
# Out:
# Processing Category: Accessories
#
# Processing Category: Accessories Sets & Packages
#
# Processing Category: Additional Accessories
#
# Processing Category: Alcoholic Beverages
#
# Processing Category: Amplifiers & Mixers
#
# Processing Category: Anklets
#
# Processing Category: Art Supplies
#
# Processing Category: Audio & Video Cables & Converters
#
# Processing Category: Automobile Exterior Accessories
#
# Processing Category: Automobile Interior Accessories
#
# Processing Category: Automobile Spare Parts
#
# Processing Category: Automotive Care
#
# Processing Category: Automotive Keychains & Key Covers
#
# Processing Category: Automotive Oils & Lubes
#
# Processing Category: Automotive Tools
#
# Processing Category: Baby & Kids Accessories
#
# Processing Category: Baby Clothes
#
# Processing Category: Baby Healthcare
#
# Processing Category: Baby Mittens & Footwear
#
# Processing Category: Baby Safety
#
# Processing Category: Baby Travel Essentials
#
# Processing Category: Backpacks
#
# Processing Category: Bag Accessories
#
# Processing Category: Bakery
#
# Processing Category: Baking Needs
#
# Processing Category: Bath & Body Care
#
# Processing Category: Bathrooms
#
# Processing Category: Batteries
#
# Processing Category: Beauty Sets & Packages
#
# Processing Category: Beauty Tools
#
# Processing Category: Bedding
#
# Processing Category: Belts
#
# Processing Category: Beverages
#
# Processing Category: Books
#
# Processing Category: Boots
#
# Processing Category: Boy Clothes
#
# Processing Category: Boy Shoes
#
# Processing Category: Bracelets & Bangles
#
# Processing Category: Breakfast Cereals & Spread
#
# Processing Category: Briefcases
#
# Processing Category: CD, DVD & Bluray
#
# Processing Category: Camera Accessories
#
# Processing Category: Camera Care
#
# Processing Category: Cameras
#
# Processing Category: Clutches
# Skipping Clutches: not enough data or variation
#
# Processing Category: Clutches & Wristlets
#
# Processing Category: Collectible Items
#
# Processing Category: Console Accessories
#
# Processing Category: Console Machines
#
# Processing Category: Convenience / Ready
#
# Processing Category: Cooking Essentials
#
# Processing Category: Costumes
#
# Processing Category: Crossbody & Shoulder Bags
#
# Processing Category: Dairy & Eggs
#
# Processing Category: Data Storage
#
# Processing Category: Decoration
#
# Processing Category: Desktop & Laptop Components
#
# Processing Category: Desktop Computers
#
# Processing Category: Diapering & Potty
#
# Processing Category: Dinnerware
#
# Processing Category: Dresses
#
# Processing Category: Drone Accessories
#
# Processing Category: Drones
#
# Processing Category: E
#
# Processing Category: Earphones, Headphones & Headsets
#
# Processing Category: Earrings
#
# Processing Category: Electrical Circuitry & Parts
#
# Processing Category: Events & Attractions
#
# Processing Category: Eyewear
#
# Processing Category: Fabric
#
# Processing Category: Feeding Essentials
#
# Processing Category: Fengshui & Religious Supplies
#
# Processing Category: Flat Sandals & Flip Flops
#
# Processing Category: Flats
#
# Processing Category: Food Staples
#
# Processing Category: Food Supplement
#
# Processing Category: Fresh & Frozen Food
#
# Processing Category: Furniture
#
# Processing Category: Gardening
#
# Processing Category: Gift & Wrapping
#
# Processing Category: Gift Set & Hampers
#
# Processing Category: Gift Sets & Packages
#
# Processing Category: Girl Clothes
#
# Processing Category: Girl Shoes
#
# Processing Category: Gloves
#
# Processing Category: Hair Accessories
#
# Processing Category: Hair Care
#
# Processing Category: Hand Warmers, Hot Water Bags & Ice Bags
#
# Processing Category: Hand, Foot & Nail Care
#
# Processing Category: Hats & Caps
#
# Processing Category: Heels
#
# Processing Category: Home Audio & Speakers
#
# Processing Category: Home Care Supplies
#
# Processing Category: Home Fragrance & Aromatherapy
#
# Processing Category: Home Organizers
#
# Processing Category: Hoodies & Sweatshirts
#
# Processing Category: Innerwear & Underwear
#
# Processing Category: Investment Precious Metals
#
# Processing Category: Jackets, Coats & Vests
#
# Processing Category: Jeans
#
# Processing Category: Jumpsuits, Playsuits & Overalls
#
# Processing Category: Keyboards & Mice
#
# Processing Category: Kitchen Appliances
#
# Processing Category: Kitchenware
#
# Processing Category: Laptop Bags
#
# Processing Category: Laptops
#
# Processing Category: Large Household Appliances
#
# Processing Category: Lens Accessories
#
# Processing Category: Lenses
#
# Processing Category: Letters & Envelopes
#
# Processing Category: Lighting
#
# Processing Category: Lingerie & Underwear
#
# Processing Category: Litter & Toilet
#
# Processing Category: Loafers & Boat Shoes
#
# Processing Category: Luggage
#
# Processing Category: Magazines & Newspaper
#
# Processing Category: Makeup
#
# Processing Category: Maternity Accessories
#
# Processing Category: Maternity Healthcare
#
# Processing Category: Maternity Wear
#
# Processing Category: Media Players
#
# Processing Category: Medical Supplies
#
# Processing Category: Men Muslim Wear
#
# Processing Category: Men Watches
#
# Processing Category: Men's Care
#
# Processing Category: Microphones
#
# Processing Category: Milk Formula & Baby Food
#
# Processing Category: Mobile Phones
#
# Processing Category: Monitors
#
# Processing Category: Motorcycle Accessories
#
# Processing Category: Motorcycle Helmets & Accessories
#
# Processing Category: Motorcycle Spare Parts
#
# Processing Category: Musical Instruments & Accessories
#
# Processing Category: Necklaces
#
# Processing Category: Neckties, Bow Ties & Cravats
#
# Processing Category: Needlework
#
# Processing Category: Network Components
#
# Processing Category: Notebooks & Papers
#
# Processing Category: Nursery
#
# Processing Category: Occupational Attire
#
# Processing Category: Office Equipment
#
# Processing Category: Others
#
# Processing Category: Oxfords & Lace
#
# Processing Category: Pants
#
# Processing Category: Pants & Leggings
#
# Processing Category: Party Supplies
#
# Processing Category: Perfumes & Fragrances
#
# Processing Category: Peripherals & Accessories
#
# Processing Category: Personal Care
#
# Processing Category: Pet Accessories
#
# Processing Category: Pet Clothing & Accessories
#
# Processing Category: Pet Food
#
# Processing Category: Pet Grooming
#
# Processing Category: Pet Healthcare
#
# Processing Category: Photo Albums
#
# Processing Category: Prayer Attire & Equipment
#
# Processing Category: Printers & Scanners
#
# Processing Category: Projectors & Accessories
#
# Processing Category: Remote Controls
#
# Processing Category: Rings
#
# Processing Category: Safety & Security
#
# Processing Category: Sandals & Flip Flops
#
# Processing Category: Scarves & Shawls
#
# Processing Category: School & Office Equipment
#
# Processing Category: Security Cameras & Systems
#
# Processing Category: Services
#
# Processing Category: Set & Couple Watches
#
# Processing Category: Sets
#
# Processing Category: Sexual Wellness
#
# Processing Category: Shoe Care & Accessories
#
# Processing Category: Shopping
#
# Processing Category: Shorts
#
# Processing Category: Sim Cards
#
# Processing Category: Skincare
#
# Processing Category: Skirts
#
# Processing Category: Sleepwear
#
# Processing Category: Sleepwear & Pajamas
#
# Processing Category: Slip Ons & Mules
#
# Processing Category: Small Household Appliances
#
# Processing Category: Snacks
#
# Processing Category: Sneakers
#
# Processing Category: Socks
#
# Processing Category: Socks & Stockings
#
# Processing Category: Softwares
#
# Processing Category: Souvenirs
#
# Processing Category: Sports & Outdoor Accessories
#
# Processing Category: Sports & Outdoor Apparels
#
# Processing Category: Sports & Outdoor Recreation Equipments
#
# Processing Category: Sports Footwear
#
# Processing Category: Suits
#
# Processing Category: Sweaters & Cardigans
#
# Processing Category: TVs & Accessories
#
# Processing Category: Tablets
#
# Processing Category: Telco
#
# Processing Category: Tools & Home Improvement
#
# Processing Category: Top
#
# Processing Category: Tops
#
# Processing Category: Tote Bags
#
# Processing Category: Toys
#
# Processing Category: Toys & Games
#
# Processing Category: Traditional Wear
#
# Processing Category: Travel Accessories
#
# Processing Category: Travel Bags
#
# Processing Category: Utilities
#
# Processing Category: Video Games
#
# Processing Category: Waist Bags & Chest Bags
#
# Processing Category: Walkie Talkies
#
# Processing Category: Wallets
#
# Processing Category: Watches Accessories
#
# Processing Category: Wearable Devices
#
# Processing Category: Wedding Dresses
#
# Processing Category: Wedges
#
# Processing Category: Women Muslim Wear
#
# Processing Category: Women Watches
#
# Processing Category: Writing & Correction
#
# ✅ Hybrid forecasts saved to: hybrid_sarima_lstm_forecasts.csv
#       category forecast_date  predicted_sold_per_month
# 0  Accessories    2025-12-01               39714003.36
# 1  Accessories    2026-01-01               38966048.66
# 2  Accessories    2026-02-01               39160454.72
# 3  Accessories    2026-03-01               40002218.83
# 4  Accessories    2026-04-01               40203148.68

# %%
# --- Evaluation Metrics: RMSE, MAE, MAPE ---
from sklearn.metrics import mean_squared_error, mean_absolute_error

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    nonzero = y_true != 0
    return np.mean(np.abs((y_true[nonzero] - y_pred[nonzero]) / y_true[nonzero])) * 100 if np.any(nonzero) else np.nan

# Evaluate only for categories with enough data and actuals available
metrics = []
for cat in category_data['second-level_category'].unique():
    data_cat = category_data[category_data['second-level_category'] == cat]
    ts = data_cat.set_index('month')['sold/m']
    if len(ts) < 18 or ts.sum() == 0 or ts.nunique() == 1:
        continue
    # Get actuals for the last FORECAST_STEPS months
    actuals = ts[-FORECAST_STEPS:]
    preds = hybrid_df[hybrid_df['category'] == cat]['predicted_sold_per_month'].values[:len(actuals)]
    if len(actuals) == 0 or len(preds) == 0:
        continue
    rmse = np.sqrt(mean_squared_error(actuals, preds))
    mae = mean_absolute_error(actuals, preds)
    mape = mean_absolute_percentage_error(actuals, preds)
    metrics.append({'category': cat, 'RMSE': rmse, 'MAE': mae, 'MAPE': mape})
    print(f"Category: {cat}")
    print(f"  RMSE: {rmse:.4f}")
    print(f"  MAE: {mae:.4f}")
    print(f"  MAPE: {mape:.2f}%\n")

metrics_df = pd.DataFrame(metrics)
metrics_df.head()
# Out:
# Category: Accessories
#   RMSE: 35551344.6916
#   MAE: 34775912.0008
#   MAPE: 1194.57%
#
# Category: Accessories Sets & Packages
#   RMSE: 83879.2104
#   MAE: 69651.4633
#   MAPE: 552.45%
#
# Category: Additional Accessories
#   RMSE: 249499.8460
#   MAE: 128214.0142
#   MAPE: 12.26%
#
# Category: Alcoholic Beverages
#   RMSE: 88240.6803
#   MAE: 69148.8217
#   MAPE: 550.37%
#
# Category: Amplifiers & Mixers
#   RMSE: 31429.5962
#   MAE: 15010.5833
#   MAPE: 100.00%
#
# Category: Anklets
#   RMSE: 1975.1441
#   MAE: 1822.8517
#   MAPE: 37.72%
#
# Category: Art Supplies
#   RMSE: 7007077.6798
#   MAE: 6170425.4125
#   MAPE: 802.41%
#
# Category: Audio & Video Cables & Converters
#   RMSE: 335463.6950
#   MAE: 171788.8792
#   MAPE: 1125.70%
#
# Category: Automobile Exterior Accessories
#   RMSE: 174531.9704
#   MAE: 138294.2700
#   MAPE: 111.59%
#
# Category: Automobile Interior Accessories
#   RMSE: 247171.4278
#   MAE: 228448.1567
#   MAPE: 71.84%
#
# Category: Automobile Spare Parts
#   RMSE: 2043100.2791
#   MAE: 1885847.0550
#   MAPE: 537.59%
#
# Category: Automotive Care
#   RMSE: 779402.8952
#   MAE: 656605.6042
#   MAPE: 190.40%
#
# Category: Automotive Keychains & Key Covers
#   RMSE: 32170.5979
#   MAE: 30115.1192
#   MAPE: 267.67%
#
# Category: Automotive Oils & Lubes
#   RMSE: 143458.2948
#   MAE: 131281.5625
#   MAPE: 84.78%
#
# Category: Automotive Tools
#   RMSE: 214702.3897
#   MAE: 196110.2067
#   MAPE: 487.80%
#
# Category: Baby & Kids Accessories
#   RMSE: 3080659.5451
#   MAE: 1920762.3200
#   MAPE: 346.14%
#
# Category: Baby Clothes
#   RMSE: 138933.8249
#   MAE: 116052.1992
#   MAPE: 53.26%
#
# Category: Baby Healthcare
#   RMSE: 96141.1060
#   MAE: 81250.7200
#   MAPE: 39.09%
#
# Category: Baby Mittens & Footwear
#   RMSE: 124514.8348
#   MAE: 66847.8750
#   MAPE: 808.59%
#
# Category: Baby Safety
#   RMSE: 2401287.1116
#   MAE: 1490328.3650
#   MAPE: 380.64%
#
# Category: Baby Travel Essentials
#   RMSE: 72705.8372
#   MAE: 60026.8467
#   MAPE: 262.48%
#
# Category: Backpacks
#   RMSE: 113147.9986
#   MAE: 101489.0233
#   MAPE: 491.50%
#
# Category: Bag Accessories
#   RMSE: 1413913.6989
#   MAE: 1374736.3058
#   MAPE: 2972.43%
#
# Category: Bakery
#   RMSE: 21287.0092
#   MAE: 15863.3708
#   MAPE: 103.57%
#
# Category: Baking Needs
#   RMSE: 46774.2827
#   MAE: 38847.6558
#   MAPE: 57.64%
#
# Category: Bath & Body Care
#   RMSE: 8560453.8750
#   MAE: 5247131.7500
#   MAPE: 100.00%
#
# Category: Bathrooms
#   RMSE: 5343619.2107
#   MAE: 5013990.8958
#   MAPE: 648.19%
#
# Category: Batteries
#   RMSE: 421847.9958
#   MAE: 410352.4675
#   MAPE: 848.41%
#
# Category: Beauty Sets & Packages
#   RMSE: 2037535.0405
#   MAE: 1927701.0775
#   MAPE: 997.22%
#
# Category: Beauty Tools
#   RMSE: 64877865.7242
#   MAE: 37125026.0392
#   MAPE: 3503.44%
#
# Category: Bedding
#   RMSE: 1785759.1667
#   MAE: 1292953.7733
#   MAPE: 172.56%
#
# Category: Belts
#   RMSE: 148501.4585
#   MAE: 92838.3833
#   MAPE: 120.31%
#
# Category: Beverages
#   RMSE: 3746485.8647
#   MAE: 3601536.4875
#   MAPE: 918.83%
#
# Category: Books
#   RMSE: 1240566.6750
#   MAE: 1115451.8375
#   MAPE: 641.45%
#
# Category: Boots
#   RMSE: 102525.6331
#   MAE: 95531.0317
#   MAPE: 828.40%
#
# Category: Boy Clothes
#   RMSE: 943700.1740
#   MAE: 625916.4317
#   MAPE: 164.10%
#
# Category: Boy Shoes
#   RMSE: 34039.8795
#   MAE: 27896.3108
#   MAPE: 105.07%
#
# Category: Bracelets & Bangles
#   RMSE: 271964.2546
#   MAE: 238941.6417
#   MAPE: 141.80%
#
# Category: Breakfast Cereals & Spread
#   RMSE: 44461.5965
#   MAE: 37324.8533
#   MAPE: 95.42%
#
# Category: Briefcases
#   RMSE: 2459.9844
#   MAE: 1661.0933
#   MAPE: 63.51%
#
# Category: CD, DVD & Bluray
#   RMSE: 1898.7063
#   MAE: 1028.1542
#   MAPE: 78.66%
#
# Category: Camera Accessories
#   RMSE: 97855.6864
#   MAE: 96028.9350
#   MAPE: 68.02%
#
# Category: Camera Care
#   RMSE: 35650.8179
#   MAE: 27349.3200
#   MAPE: 239.16%
#
# Category: Cameras
#   RMSE: 3483.0054
#   MAE: 2301.6975
#   MAPE: 71.43%
#
# Category: Clutches & Wristlets
#   RMSE: 79618.8835
#   MAE: 34530.1917
#   MAPE: 439.16%
#
# Category: Collectible Items
#   RMSE: 75086.7468
#   MAE: 63331.7133
#   MAPE: 62.01%
#
# Category: Console Accessories
#   RMSE: 182249.8046
#   MAE: 120347.0583
#   MAPE: 172.73%
#
# Category: Console Machines
#   RMSE: 3984.5774
#   MAE: 3664.5983
#   MAPE: 86.62%
#
# Category: Convenience / Ready
#   RMSE: 75955.5492
#   MAE: 67876.2483
#   MAPE: 114.73%
#
# Category: Cooking Essentials
#   RMSE: 416115.8230
#   MAE: 402888.8083
#   MAPE: 224.20%
#
# Category: Costumes
#   RMSE: 6829.2332
#   MAE: 6059.4433
#   MAPE: 71.52%
#
# Category: Crossbody & Shoulder Bags
#   RMSE: 3825417974682.0542
#   MAE: 1507619001640.9844
#   MAPE: 60039352.65%
#
# Category: Dairy & Eggs
#   RMSE: 242677.0054
#   MAE: 204656.6583
#   MAPE: 227.75%
#
# Category: Data Storage
#   RMSE: 52583.8434
#   MAE: 46850.4683
#   MAPE: 102.85%
#
# Category: Decoration
#   RMSE: 21487308.4361
#   MAE: 13320950.6667
#   MAPE: 100.00%
#
# Category: Desktop & Laptop Components
#   RMSE: 35611.1295
#   MAE: 33572.0208
#   MAPE: 103.16%
#
# Category: Desktop Computers
#   RMSE: 9245.9782
#   MAE: 9097.2975
#   MAPE: 143.34%
#
# Category: Diapering & Potty
#   RMSE: 102723258.1697
#   MAE: 46503329.7342
#   MAPE: 2342.77%
#
# Category: Dinnerware
#   RMSE: 35809873.0465
#   MAE: 31622937.9633
#   MAPE: 1743.59%
#
# Category: Dresses
#   RMSE: 317519.5109
#   MAE: 196290.3967
#   MAPE: 198.92%
#
# Category: Drone Accessories
#   RMSE: 811.7188
#   MAE: 773.7925
#   MAPE: 32.22%
#
# Category: Drones
#   RMSE: 13341.5972
#   MAE: 8151.0075
#   MAPE: 227.06%
#
# Category: E
#   RMSE: 54404.5597
#   MAE: 53030.0100
#   MAPE: 509.47%
#
# Category: Earphones, Headphones & Headsets
#   RMSE: 3668238.7398
#   MAE: 3385793.1308
#   MAPE: 903.15%
#
# Category: Earrings
#   RMSE: 247672.0434
#   MAE: 225005.4842
#   MAPE: 200.32%
#
# Category: Electrical Circuitry & Parts
#   RMSE: 4144256.4290
#   MAE: 3801496.7283
#   MAPE: 1186.67%
#
# Category: Events & Attractions
#   RMSE: 1226.4718
#   MAE: 1213.5358
#   MAPE: nan%
#
# Category: Eyewear
#   RMSE: 569774.6132
#   MAE: 528444.5767
#   MAPE: 202.64%
#
# Category: Fabric
#   RMSE: 278256.5664
#   MAE: 214862.8808
#   MAPE: 218.73%
#
# Category: Feeding Essentials
#   RMSE: 3771382.5056
#   MAE: 3731692.1750
#   MAPE: 614.74%
#
# Category: Fengshui & Religious Supplies
#   RMSE: 59425.8699
#   MAE: 55013.0908
#   MAPE: 198.69%
#
# Category: Flat Sandals & Flip Flops
#   RMSE: 286788.6359
#   MAE: 222858.8450
#   MAPE: 59.84%
#
# Category: Flats
#   RMSE: 252377.3361
#   MAE: 117165.2550
#   MAPE: 289.96%
#
# Category: Food Staples
#   RMSE: 1854069.9823
#   MAE: 1834256.4475
#   MAPE: 1977.19%
#
# Category: Food Supplement
#   RMSE: 1058075.2448
#   MAE: 992820.9300
#   MAPE: 227.53%
#
# Category: Fresh & Frozen Food
#   RMSE: 4761.7777
#   MAE: 3955.9933
#   MAPE: 88.51%
#
# Category: Furniture
#   RMSE: 14978959.0470
#   MAE: 12918431.5875
#   MAPE: 1249.18%
#
# Category: Gardening
#   RMSE: 1235879.7069
#   MAE: 1179873.7708
#   MAPE: 329.77%
#
# Category: Gift & Wrapping
#   RMSE: 1058489174.6795
#   MAE: 656473355.9417
#   MAPE: 14085.14%
#
# Category: Gift Set & Hampers
#   RMSE: 26101.3374
#   MAE: 23066.3842
#   MAPE: 846.94%
#
# Category: Gift Sets & Packages
#   RMSE: 1754.8208
#   MAE: 951.2025
#   MAPE: 73.40%
#
# Category: Girl Clothes
#   RMSE: 366271.8498
#   MAE: 323120.9792
#   MAPE: 102.29%
#
# Category: Girl Shoes
#   RMSE: 20368.7517
#   MAE: 19072.9208
#   MAPE: 63.82%
#
# Category: Gloves
#   RMSE: 70556.8807
#   MAE: 43486.3025
#   MAPE: 224.99%
#
# Category: Hair Accessories
#   RMSE: 1008190.3010
#   MAE: 952815.0992
#   MAPE: 163.78%
#
# Category: Hair Care
#   RMSE: 54567954.7992
#   MAE: 40552556.3883
#   MAPE: 3023.48%
#
# Category: Hand Warmers, Hot Water Bags & Ice Bags
#   RMSE: 95227640.0499
#   MAE: 55630133.8225
#   MAPE: 50251.31%
#
# Category: Hand, Foot & Nail Care
#   RMSE: 1897905.1768
#   MAE: 1455832.3433
#   MAPE: 130.04%
#
# Category: Hats & Caps
#   RMSE: 457470.8237
#   MAE: 383299.4150
#   MAPE: 261.68%
#
# Category: Heels
#   RMSE: 67263.3653
#   MAE: 55105.9325
#   MAPE: 66.19%
#
# Category: Home Audio & Speakers
#   RMSE: 208588.0696
#   MAE: 175417.3942
#   MAPE: 185.30%
#
# Category: Home Care Supplies
#   RMSE: 111438831554.5455
#   MAE: 52742970283.0825
#   MAPE: 348069.67%
#
# Category: Home Fragrance & Aromatherapy
#   RMSE: 818439.4373
#   MAE: 734463.4708
#   MAPE: 241.61%
#
# Category: Home Organizers
#   RMSE: 21419560.1298
#   MAE: 20307418.0208
#   MAPE: 1043.99%
#
# Category: Hoodies & Sweatshirts
#   RMSE: 222528.5025
#   MAE: 126735.4725
#   MAPE: 415.47%
#
# Category: Innerwear & Underwear
#   RMSE: 361237.7834
#   MAE: 231172.0333
#   MAPE: 120.57%
#
# Category: Investment Precious Metals
#   RMSE: 14074.1330
#   MAE: 11745.0342
#   MAPE: 68.38%
#
# Category: Jackets, Coats & Vests
#   RMSE: 111944.9582
#   MAE: 99276.8017
#   MAPE: 151.91%
#
# Category: Jeans
#   RMSE: 253113.3729
#   MAE: 202120.4517
#   MAPE: 121.26%
#
# Category: Jumpsuits, Playsuits & Overalls
#   RMSE: 51332.3525
#   MAE: 27894.1333
#   MAPE: 153.23%
#
# Category: Keyboards & Mice
#   RMSE: 107447.6286
#   MAE: 68231.8692
#   MAPE: 233.75%
#
# Category: Kitchen Appliances
#   RMSE: 650387.7747
#   MAE: 541675.8325
#   MAPE: 114.31%
#
# Category: Kitchenware
#   RMSE: 3581853890.6375
#   MAE: 2147950381.9050
#   MAPE: 27321.75%
#
# Category: Laptop Bags
#   RMSE: 80224.6729
#   MAE: 61018.4283
#   MAPE: 234.40%
#
# Category: Laptops
#   RMSE: 1434.9998
#   MAE: 1418.3850
#   MAPE: nan%
#
# Category: Large Household Appliances
#   RMSE: 1227477.2073
#   MAE: 1070774.3208
#   MAPE: 317.23%
#
# Category: Lens Accessories
#   RMSE: 1754.0006
#   MAE: 1203.9417
#   MAPE: nan%
#
# Category: Lenses
#   RMSE: 231.5534
#   MAE: 107.3600
#   MAPE: nan%
#
# Category: Letters & Envelopes
#   RMSE: 88164.4122
#   MAE: 80193.7100
#   MAPE: 117.75%
#
# Category: Lighting
#   RMSE: 233739932593.1466
#   MAE: 108965784580.8750
#   MAPE: 1429964.46%
#
# Category: Lingerie & Underwear
#   RMSE: 1637346.3703
#   MAE: 1344517.0117
#   MAPE: 88.37%
#
# Category: Litter & Toilet
#   RMSE: 99186347127882087925674128965632.0000
#   MAE: 28933139521658396622340078174208.0000
#   MAPE: 10539472533090691614507008.00%
#
# Category: Loafers & Boat Shoes
#   RMSE: 16675.8522
#   MAE: 12110.5550
#   MAPE: 168.88%
#
# Category: Luggage
#   RMSE: 16524.2608
#   MAE: 13534.1467
#   MAPE: 154.13%
#
# Category: Magazines & Newspaper
#   RMSE: 613.4323
#   MAE: 224.6417
#   MAPE: 100.00%
#
# Category: Makeup
#   RMSE: 10697922.7967
#   MAE: 7941367.5792
#   MAPE: 286.94%
#
# Category: Maternity Accessories
#   RMSE: 55185.3836
#   MAE: 34112.2992
#   MAPE: 424.62%
#
# Category: Maternity Healthcare
#   RMSE: 19096.7504
#   MAE: 17088.1058
#   MAPE: 129.84%
#
# Category: Maternity Wear
#   RMSE: 630336.4939
#   MAE: 276957.0683
#   MAPE: 625.04%
#
# Category: Media Players
#   RMSE: 8962.1925
#   MAE: 5623.7617
#   MAPE: 59.58%
#
# Category: Medical Supplies
#   RMSE: 15463928.9010
#   MAE: 15315516.9650
#   MAPE: 899.74%
#
# Category: Men Muslim Wear
#   RMSE: 4182.3747
#   MAE: 4112.8525
#   MAPE: 32.69%
#
# Category: Men Watches
#   RMSE: 242984.1051
#   MAE: 124021.4683
#   MAPE: 334.61%
#
# Category: Men's Care
#   RMSE: 2051841.5241
#   MAE: 1995340.7658
#   MAPE: 2190.98%
#
# Category: Microphones
#   RMSE: 128341.4570
#   MAE: 88886.3050
#   MAPE: 336.46%
#
# Category: Milk Formula & Baby Food
#   RMSE: 44493.1730
#   MAE: 36390.6500
#   MAPE: 292.31%
#
# Category: Mobile Phones
#   RMSE: 35402.4158
#   MAE: 31380.0675
#   MAPE: 55.20%
#
# Category: Monitors
#   RMSE: 353.5576
#   MAE: 159.1492
#   MAPE: 4.94%
#
# Category: Motorcycle Accessories
#   RMSE: 803762.4873
#   MAE: 732276.1508
#   MAPE: 154.49%
#
# Category: Motorcycle Helmets & Accessories
#   RMSE: 780005.1686
#   MAE: 503794.6767
#   MAPE: 486.44%
#
# Category: Motorcycle Spare Parts
#   RMSE: 14364788914.0320
#   MAE: 7076676847.1508
#   MAPE: 178051.05%
#
# Category: Musical Instruments & Accessories
#   RMSE: 141758.7227
#   MAE: 104709.4783
#   MAPE: 527.24%
#
# Category: Necklaces
#   RMSE: 140273.1800
#   MAE: 99050.9167
#   MAPE: 100.00%
#
# Category: Neckties, Bow Ties & Cravats
#   RMSE: 31893.2153
#   MAE: 22400.4117
#   MAPE: 239.40%
#
# Category: Needlework
#   RMSE: 628937.3326
#   MAE: 429495.0692
#   MAPE: 79.45%
#
# Category: Network Components
#   RMSE: 163674.5446
#   MAE: 143408.3333
#   MAPE: 228.90%
#
# Category: Notebooks & Papers
#   RMSE: 5127830.3668
#   MAE: 3731413.8333
#   MAPE: 100.00%
#
# Category: Nursery
#   RMSE: 328499.9505
#   MAE: 246881.0517
#   MAPE: 546.51%
#
# Category: Occupational Attire
#   RMSE: 789228.3288
#   MAE: 485390.6100
#   MAPE: 2777.43%
#
# Category: Office Equipment
#   RMSE: 6993.1593
#   MAE: 5090.5092
#   MAPE: 61.94%
#
# Category: Others
#   RMSE: 580069.5885
#   MAE: 568446.0933
#   MAPE: 101.42%
#
# Category: Oxfords & Lace
#   RMSE: 143071.5190
#   MAE: 93427.6000
#   MAPE: 513.12%
#
# Category: Pants
#   RMSE: 158812.5412
#   MAE: 139242.9000
#   MAPE: 61.86%
#
# Category: Pants & Leggings
#   RMSE: 367448.4561
#   MAE: 242585.0433
#   MAPE: 66.75%
#
# Category: Party Supplies
#   RMSE: 5484740.3149
#   MAE: 4780297.4900
#   MAPE: 522.16%
#
# Category: Perfumes & Fragrances
#   RMSE: 162711690435554.4688
#   MAE: 60707424813544.2422
#   MAPE: 420105165.31%
#
# Category: Peripherals & Accessories
#   RMSE: 702827.8389
#   MAE: 644651.9000
#   MAPE: 672.93%
#
# Category: Personal Care
#   RMSE: 9649234.5184
#   MAE: 9592793.1933
#   MAPE: 897.58%
#
# Category: Pet Accessories
#   RMSE: 59332282.5788
#   MAE: 46924765.1925
#   MAPE: 4140.59%
#
# Category: Pet Clothing & Accessories
#   RMSE: 404969.8541
#   MAE: 391034.9833
#   MAPE: 969.51%
#
# Category: Pet Food
#   RMSE: 127792700.7416
#   MAE: 98840100.4367
#   MAPE: 3293.56%
#
# Category: Pet Grooming
#   RMSE: 3458344.9476
#   MAE: 2782727.7667
#   MAPE: 1566.05%
#
# Category: Pet Healthcare
#   RMSE: 1320280.4560
#   MAE: 1239131.6800
#   MAPE: 403.23%
#
# Category: Photo Albums
#   RMSE: 188471.1416
#   MAE: 168988.4450
#   MAPE: 353.64%
#
# Category: Prayer Attire & Equipment
#   RMSE: 1536.9710
#   MAE: 890.0058
#   MAPE: 48.10%
#
# Category: Printers & Scanners
#   RMSE: 172115.5238
#   MAE: 113250.4542
#   MAPE: 294.02%
#
# Category: Projectors & Accessories
#   RMSE: 88311.0520
#   MAE: 77420.0317
#   MAPE: 1070.22%
#
# Category: Remote Controls
#   RMSE: 76573.4507
#   MAE: 70473.8967
#   MAPE: 601.71%
#
# Category: Rings
#   RMSE: 3403923089.5260
#   MAE: 1634164422.4908
#   MAPE: 1944745.81%
#
# Category: Safety & Security
#   RMSE: 7488016.9199
#   MAE: 6411186.2792
#   MAPE: 1531.57%
#
# Category: Sandals & Flip Flops
#   RMSE: 349318.3443
#   MAE: 245070.8133
#   MAPE: 65.10%
#
# Category: Scarves & Shawls
#   RMSE: 76598.9067
#   MAE: 49326.0025
#   MAPE: 58.01%
#
# Category: School & Office Equipment
#   RMSE: 6007172.2190
#   MAE: 5607203.3683
#   MAPE: 370.55%
#
# Category: Security Cameras & Systems
#   RMSE: 76188.0338
#   MAE: 70859.0258
#   MAPE: 84.83%
#
# Category: Services
#   RMSE: 2180.5608
#   MAE: 2131.6075
#   MAPE: nan%
#
# Category: Set & Couple Watches
#   RMSE: 85100.5308
#   MAE: 66239.5067
#   MAPE: 474.55%
#
# Category: Sets
#   RMSE: 252523.8075
#   MAE: 127752.7083
#   MAPE: 160.12%
#
# Category: Sexual Wellness
#   RMSE: 95851.8251
#   MAE: 80475.6042
#   MAPE: 95.51%
#
# Category: Shoe Care & Accessories
#   RMSE: 171819.2463
#   MAE: 161103.2692
#   MAPE: 56.41%
#
# Category: Shopping
#   RMSE: 298.9070
#   MAE: 294.4950
#   MAPE: nan%
#
# Category: Shorts
#   RMSE: 1228061.3763
#   MAE: 774146.6375
#   MAPE: 88.41%
#
# Category: Sim Cards
#   RMSE: 290012.8347
#   MAE: 178010.0792
#   MAPE: 127.52%
#
# Category: Skincare
#   RMSE: 16956119.6542
#   MAE: 16735833.6150
#   MAPE: 913.30%
#
# Category: Skirts
#   RMSE: 96462.7137
#   MAE: 70586.2208
#   MAPE: 335.77%
#
# Category: Sleepwear
#   RMSE: 8630.2937
#   MAE: 7382.5200
#   MAPE: 127.06%
#
# Category: Sleepwear & Pajamas
#   RMSE: 270253.5221
#   MAE: 148592.6983
#   MAPE: 110.07%
#
# Category: Slip Ons & Mules
#   RMSE: 39708.2387
#   MAE: 31174.9400
#   MAPE: 223.04%
#
# Category: Small Household Appliances
#   RMSE: 205040.2402
#   MAE: 191100.3833
#   MAPE: 324.31%
#
# Category: Snacks
#   RMSE: 932921.0462
#   MAE: 753450.0658
#   MAPE: 154.03%
#
# Category: Sneakers
#   RMSE: 262927.0277
#   MAE: 173407.2217
#   MAPE: 117.85%
#
# Category: Socks
#   RMSE: 554948.1948
#   MAE: 491852.5525
#   MAPE: 221.08%
#
# Category: Socks & Stockings
#   RMSE: 362021.4951
#   MAE: 287638.1717
#   MAPE: 140.09%
#
# Category: Softwares
#   RMSE: 2352.2139
#   MAE: 1175.3333
#   MAPE: 100.00%
#
# Category: Souvenirs
#   RMSE: 931864.6941
#   MAE: 849904.2392
#   MAPE: 176.00%
#
# Category: Sports & Outdoor Accessories
#   RMSE: 9486140.0636
#   MAE: 8789724.2650
#   MAPE: 1103.07%
#
# Category: Sports & Outdoor Apparels
#   RMSE: 635463.8844
#   MAE: 491648.3825
#   MAPE: 127.74%
#
# Category: Sports & Outdoor Recreation Equipments
#   RMSE: 66212003.4003
#   MAE: 31675958.4350
#   MAPE: 2431.59%
#
# Category: Sports Footwear
#   RMSE: 49207.5967
#   MAE: 39788.8892
#   MAPE: 231.70%
#
# Category: Suits
#   RMSE: 17149.1531
#   MAE: 15138.9808
#   MAPE: 147.02%
#
# Category: Sweaters & Cardigans
#   RMSE: 82493.3359
#   MAE: 46476.8942
#   MAPE: 466.27%
#
# Category: TVs & Accessories
#   RMSE: 9447.6546
#   MAE: 8167.9775
#   MAPE: 42.13%
#
# Category: Tablets
#   RMSE: 39784.2576
#   MAE: 35711.2308
#   MAPE: 573.81%
#
# Category: Telco
#   RMSE: 60427.8302
#   MAE: 60104.0967
#   MAPE: nan%
#
# Category: Tools & Home Improvement
#   RMSE: 717966262.1603
#   MAE: 347744032.6333
#   MAPE: 3758.99%
#
# Category: Top
#   RMSE: 32993.3280
#   MAE: 25990.8550
#   MAPE: 34.85%
#
# Category: Tops
#   RMSE: 2218223.1807
#   MAE: 1416638.4342
#   MAPE: 81.95%
#
# Category: Tote Bags
#   RMSE: 2341745.8315
#   MAE: 2227913.8483
#   MAPE: 706.92%
#
# Category: Toys
#   RMSE: 604046267222.4575
#   MAE: 262863130180.8450
#   MAPE: 3282408.56%
#
# Category: Toys & Games
#   RMSE: 118094.1664
#   MAE: 109562.4900
#   MAPE: 171.37%
#
# Category: Traditional Wear
#   RMSE: 31193.7164
#   MAE: 20647.5925
#   MAPE: 75.36%
#
# Category: Travel Accessories
#   RMSE: 4074287.4531
#   MAE: 3997232.2467
#   MAPE: 689.03%
#
# Category: Travel Bags
#   RMSE: 534055.0458
#   MAE: 508627.1400
#   MAPE: 455.47%
#
# Category: Utilities
#   RMSE: 150.0359
#   MAE: 148.0758
#   MAPE: nan%
#
# Category: Video Games
#   RMSE: 166567.8746
#   MAE: 54671.7167
#   MAPE: 1266.64%
#
# Category: Waist Bags & Chest Bags
#   RMSE: 139977.8633
#   MAE: 126696.1892
#   MAPE: 227.18%
#
# Category: Walkie Talkies
#   RMSE: 11382.4772
#   MAE: 9172.1875
#   MAPE: 226.62%
#
# Category: Wallets
#   RMSE: 1848882.0167
#   MAE: 1724141.1308
#   MAPE: 636.59%
#
# Category: Watches Accessories
#   RMSE: 30671.0233
#   MAE: 19127.3367
#   MAPE: 158.05%
#
# Category: Wearable Devices
#   RMSE: 70619.4332
#   MAE: 61645.0283
#   MAPE: 172.83%
#
# Category: Wedding Dresses
#   RMSE: 9694.0691
#   MAE: 2945.5175
#   MAPE: 100.00%
#
# Category: Wedges
#   RMSE: 107545.8681
#   MAE: 86980.9017
#   MAPE: 190.55%
#
# Category: Women Muslim Wear
#   RMSE: 14436.0513
#   MAE: 13129.0942
#   MAPE: 57.81%
#
# Category: Women Watches
#   RMSE: 198555.1911
#   MAE: 167234.8592
#   MAPE: 241.62%
#
# Category: Writing & Correction
#   RMSE: 5125055.7158
#   MAE: 4354953.5092
#   MAPE: 272.40%
#                       category          RMSE           MAE         MAPE
# 0                  Accessories  3.555134e+07  3.477591e+07  1194.573836
# 1  Accessories Sets & Packages  8.387921e+04  6.965146e+04   552.453204
# 2       Additional Accessories  2.494998e+05  1.282140e+05    12.260387
# 3          Alcoholic Beverages  8.824068e+04  6.914882e+04   550.373733
# 4          Amplifiers & Mixers  3.142960e+04  1.501058e+04   100.000000

# %%
# Display metrics table for first 10 categories
metrics_df = pd.DataFrame(metrics)
print(f"\n✅ Evaluation complete for {len(metrics_df)} categories")
metrics_df.head(10)
# Out:
# ✅ Evaluation complete for 214 categories
#                             category          RMSE           MAE         MAPE
# 0                        Accessories  3.555134e+07  3.477591e+07  1194.573836
# 1        Accessories Sets & Packages  8.387921e+04  6.965146e+04   552.453204
# 2             Additional Accessories  2.494998e+05  1.282140e+05    12.260387
# 3                Alcoholic Beverages  8.824068e+04  6.914882e+04   550.373733
# 4                Amplifiers & Mixers  3.142960e+04  1.501058e+04   100.000000
# 5                            Anklets  1.975144e+03  1.822852e+03    37.722886
# 6                       Art Supplies  7.007078e+06  6.170425e+06   802.406606
# 7  Audio & Video Cables & Converters  3.354637e+05  1.717889e+05  1125.698528
# 8    Automobile Exterior Accessories  1.745320e+05  1.382943e+05   111.587263
# 9    Automobile Interior Accessories  2.471714e+05  2.284482e+05    71.838544
