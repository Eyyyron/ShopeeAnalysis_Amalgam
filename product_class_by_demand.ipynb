# %% [markdown]
# ### Imports and Settings
# This cell imports all necessary libraries for data manipulation, visualization, and time-series analysis.
# It also sets some global variables for minimum months of data and plotting styles.

# %%
# Cell 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ### Load Data
# This cell loads the consolidated CSV containing product sales over time and displays the first few rows
# to verify the data loaded correctly.

# %%
# Cell 2: Load Seasonal Decomposition Results from Member 2
import pandas as pd
import numpy as np

# Load the decomposition results from Member 2
df = pd.read_csv('seasonal_decomposition_results.csv')

print("=" * 80)
print("SEASONAL DECOMPOSITION RESULTS LOADED")
print("=" * 80)
print(f"\nDataset shape: {df.shape}")
print(f"\nColumns:")
for i, col in enumerate(df.columns):
    print(f"   [{i}] {col}")

# Check for required columns
required_cols = ['product', 'category', 'mean_monthly_sales', 'seasonal_amplitude', 'trend_slope']
missing_cols = [col for col in required_cols if col not in df.columns]

if missing_cols:
    print(f"\nWARNING: Missing required columns: {missing_cols}")
    print("Please coordinate with Member 2 to include these columns.")
else:
    print(f"\nAll required columns present!")

# Display summary
print(f"\nData Summary:")
print(f"   Total products: {df['product'].nunique()}")
print(f"   Total categories: {df['category'].nunique()}")

print(f"\nCategories:")
for cat in df['category'].unique():
    count = df[df['category'] == cat].shape[0]
    print(f"   - {cat}: {count} products")

print(f"\nSample data:")
print(df.head(10))

print(f"\nReady for classification!")
# Out:
# ================================================================================
# SEASONAL DECOMPOSITION RESULTS LOADED
# ================================================================================
#
# Dataset shape: (25228, 6)
#
# Columns:
#    [0] product
#    [1] category
#    [2] mean_monthly_sales
#    [3] seasonal_amplitude
#    [4] trend_slope
#    [5] max_residual_zscore
#
# All required columns present!
#
# Data Summary:
#    Total products: 25228
#    Total categories: 30
#
# Categories:
#    - Fashion Accessories: 1164 products
#    - Motorcycles: 523 products
#    - Home & Living: 5625 products
#    - Sports & Outdoors: 814 products
#    - Women Clothes: 1835 products
#    - Beauty: 2632 products
#    - Hobbies & Collections: 415 products
#    - Home Appliances: 737 products
#    - Pets: 825 products
#    - Mobile & Gadgets: 1641 products
#    - Baby & Kids Fashion: 918 products
#    - Automobiles: 409 products
#    - Stationery: 1584 products
#    - Health: 1100 products
#    - Men Clothes: 756 products
#    - Watches: 86 products
#    - Men Bags: 97 products
#    - Women Shoes: 507 products
#    - Women Bags: 494 products
#    - Mom & Baby: 952 products
#    - Food & Beverages: 689 products
#    - Travel & Luggage: 244 products
#    - Audio: 351 products
#    - Gaming & Consoles: 38 products
#    - Computers & Accessories: 330 products
#    - Books & Magazines: 76 products
#    - Men Shoes: 250 products
#    - Cameras & Drones: 122 products
#    - Tickets, Vouchers & Services: 10 products
#    - Muslim Fashion: 4 products
#
# Sample data:
#                                              product               category  \
# 0    One Piece Pearl Cherry Clavicle Necklace Sui...    Fashion Accessories
# 1   1PC Motorcycle/Car New 3 LED Round Module Lig...            Motorcycles
# 2   3D Foam Brick Wall Sticker with Realistic Bri...          Home & Living
# 3                        4-Digit Sports Score Board       Sports & Outdoors
# 4   5 Pairs Korean Style Cute Socks - Trendy Ins ...          Women Clothes
# 5   60ml Oil Based Perfume for WOMEN by CENTRAL F...                 Beauty
# 6   Blind Sewing Needles Elderly Big Hole Stainle...  Hobbies & Collections
# 7   FARDLY Women's Panties Breathable Underwear W...          Women Clothes
# 8   High-Quality Raincoat Jacket and Pants Set wi...      Sports & Outdoors
# 9             Maxell Alkaline Button Cell Batteries         Home Appliances
#
#    mean_monthly_sales  seasonal_amplitude  trend_slope  max_residual_zscore
# 0          528.600000            7.943303   -62.339991             3.374276
# 1          935.303030            2.857529   -70.728993             3.169583
# 2        10988.589744            3.572459   -98.542156             5.091260
# 3          179.866667          255.000000     0.850315             4.394109
# 4          232.416667            6.415706   -49.393808             2.241386
# 5         9104.155556            2.947392   476.282591             5.107200
# 6          215.307692          221.000000     1.036667             4.079828
# 7          315.884615            8.224894   -29.687100             3.462448
# 8          444.807692          221.000000     2.141667             4.079828
# 9          284.244444            3.253012    41.830881             1.965622
#
# Ready for classification!

# %% [markdown]
# ### Data Preparation and Aggregation
# Aggregate data by product and month for analysis

# %%
# Cell 3: Prepare Data for Classification

print("=" * 80)
print("DATA PREPARATION - USING DECOMPOSITION METRICS")
print("=" * 80)

column_mapping = {}

# Check for alternative column names and standardize
if 'seasonal_strength' in df.columns and 'seasonal_amplitude' not in df.columns:
    column_mapping['seasonal_strength'] = 'seasonal_amplitude'
    print("Using 'seasonal_strength' as 'seasonal_amplitude'")

if 'avg_monthly_sales' in df.columns and 'mean_monthly_sales' not in df.columns:
    column_mapping['avg_monthly_sales'] = 'mean_monthly_sales'
    print("Using 'avg_monthly_sales' as 'mean_monthly_sales'")

if column_mapping:
    df = df.rename(columns=column_mapping)

# Verify required columns exist
required_columns = ['product', 'category', 'mean_monthly_sales', 'seasonal_amplitude', 'trend_slope']

print(f"\nChecking for required columns:")
for col in required_columns:
    exists = col in df.columns
    symbol = "PASS" if exists else "FAIL"
    print(f"   [{symbol}] {col}")

if not all(col in df.columns for col in required_columns):
    print("\nERROR: Missing required columns!")
    print("Cannot proceed with classification.")
else:
    print(f"\nAll required columns present!")
    print(f"\nData ready for classification:")
    print(f"   Products: {len(df)}")
    print(f"   Categories: {df['category'].nunique()}")
    
    # Display data summary
    print(f"\nMetrics Summary:")
    print(df[['mean_monthly_sales', 'seasonal_amplitude', 'trend_slope']].describe())
# Out:
# ================================================================================
# DATA PREPARATION - USING DECOMPOSITION METRICS
# ================================================================================
#
# Checking for required columns:
#    [PASS] product
#    [PASS] category
#    [PASS] mean_monthly_sales
#    [PASS] seasonal_amplitude
#    [PASS] trend_slope
#
# All required columns present!
#
# Data ready for classification:
#    Products: 25228
#    Categories: 30
#
# Metrics Summary:
#        mean_monthly_sales  seasonal_amplitude   trend_slope
# count        25228.000000        25228.000000  25228.000000
# mean           746.077101           18.618447     -9.261040
# std           5114.425114           36.497179    248.146643
# min              0.000000            0.000000 -27838.214143
# 25%             60.234163            4.885611    -13.321977
# 50%            148.400000            8.894620     -2.211501
# 75%            437.450000           16.234967      4.237078
# max         355084.400000          300.000000   7926.994035

# %% [markdown]
# ### Define Classification Metrics
# This cell calculates key metrics for demand classification:
# 1. Coefficient of Variation (CV) - measures stability
# 2. Seasonal Index Amplitude - measures seasonality strength
# 3. Trend Slope - measures growth/decline pattern

# %%
# Cell 4: Prepare Metrics DataFrame

# Dataframe to hold metrics for classification
metrics_df = df.copy()

# Ensure we have coefficient of variation (if not provided, calculate it)
if 'coefficient_of_variation' not in metrics_df.columns:
    if 'std_monthly_sales' in metrics_df.columns:
        print("Calculating coefficient of variation from provided std...")
        metrics_df['coefficient_of_variation'] = (
            metrics_df['std_monthly_sales'] / metrics_df['mean_monthly_sales']
        )
    else:
        print("WARNING: No 'coefficient_of_variation' or 'std_monthly_sales' provided")
        print("Setting CV to NaN - will need to handle in classification")
        metrics_df['coefficient_of_variation'] = np.nan

# Add n_months if not provided (default to some reasonable value)
if 'n_months' not in metrics_df.columns:
    print("'n_months' not provided, setting to 12 (minimum for decomposition)")
    metrics_df['n_months'] = 12

# Quick approximation if std is not available
if 'coefficient_of_variation' not in metrics_df.columns or metrics_df['coefficient_of_variation'].isna().all():
    if 'seasonal_amplitude' in metrics_df.columns:
        metrics_df['coefficient_of_variation'] = metrics_df['seasonal_amplitude'] * 0.5
        print("Estimated CV from seasonal_amplitude (CV ≈ seasonal_amplitude * 0.5)")
    else:
        metrics_df['coefficient_of_variation'] = np.nan
        print("No seasonal_amplitude available — CV remains NaN")

print("=" * 80)
print("METRICS DATAFRAME PREPARED")
print("=" * 80)
print(f"\nUsing decomposition metrics from Member 2")
print(f"Total products: {len(metrics_df)}")

print(f"\nColumns in metrics_df:")
for col in metrics_df.columns:
    print(f"   - {col}")

print(f"\nSample metrics:")
print(metrics_df.head())

print(f"\nReady for classification!")
# Out:
# WARNING: No 'coefficient_of_variation' or 'std_monthly_sales' provided
# Setting CV to NaN - will need to handle in classification
# 'n_months' not provided, setting to 12 (minimum for decomposition)
# Estimated CV from seasonal_amplitude (CV ≈ seasonal_amplitude * 0.5)
# ================================================================================
# METRICS DATAFRAME PREPARED
# ================================================================================
#
# Using decomposition metrics from Member 2
# Total products: 25228
#
# Columns in metrics_df:
#    - product
#    - category
#    - mean_monthly_sales
#    - seasonal_amplitude
#    - trend_slope
#    - max_residual_zscore
#    - coefficient_of_variation
#    - n_months
#
# Sample metrics:
#                                              product             category  \
# 0    One Piece Pearl Cherry Clavicle Necklace Sui...  Fashion Accessories
# 1   1PC Motorcycle/Car New 3 LED Round Module Lig...          Motorcycles
# 2   3D Foam Brick Wall Sticker with Realistic Bri...        Home & Living
# 3                        4-Digit Sports Score Board     Sports & Outdoors
# 4   5 Pairs Korean Style Cute Socks - Trendy Ins ...        Women Clothes
#
#    mean_monthly_sales  seasonal_amplitude  trend_slope  max_residual_zscore  \
# 0          528.600000            7.943303   -62.339991             3.374276
# 1          935.303030            2.857529   -70.728993             3.169583
# 2        10988.589744            3.572459   -98.542156             5.091260
# 3          179.866667          255.000000     0.850315             4.394109
# 4          232.416667            6.415706   -49.393808             2.241386
#
#    coefficient_of_variation  n_months
# 0                  3.971651        12
# 1                  1.428764        12
# 2                  1.786230        12
# 3                127.500000        12
# 4                  3.207853        12
#
# Ready for classification!

# %% [markdown]
# ### Display Metric Statistics

# %%
# Cell 5: Display Metric Statistics
print("=" * 80)
print("DEMAND CLASSIFICATION METRICS - SUMMARY STATISTICS")
print("=" * 80)

print("\nCoefficient of Variation (CV)")
print("-" * 50)
print(metrics_df['coefficient_of_variation'].describe())
print("\nInterpretation:")
print("  - CV < 0.3: Stable demand")
print("  - 0.3 <= CV < 0.7: Moderate variability")
print("  - CV >= 0.7: High variability")

print("\n" + "=" * 80)
print("\nSeasonal Amplitude")
print("-" * 50)
print(metrics_df['seasonal_amplitude'].describe())
print("\nInterpretation:")
print("  - Amplitude < 0.5: Weak seasonality")
print("  - 0.5 <= Amplitude < 1.0: Moderate seasonality")
print("  - Amplitude >= 1.0: Strong seasonality")

print("\n" + "=" * 80)
print("\nMean Monthly Sales")
print("-" * 50)
print(metrics_df['mean_monthly_sales'].describe())

# Visualize distributions
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# CV distribution
axes[0, 0].hist(metrics_df['coefficient_of_variation'].dropna(), bins=30, 
                edgecolor='black', alpha=0.7)
axes[0, 0].set_xlabel('Coefficient of Variation')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Distribution of CV')
axes[0, 0].axvline(x=0.3, color='r', linestyle='--', label='CV=0.3')
axes[0, 0].axvline(x=0.7, color='orange', linestyle='--', label='CV=0.7')
axes[0, 0].legend()

# Seasonal amplitude distribution
axes[0, 1].hist(metrics_df['seasonal_amplitude'], bins=30, 
                edgecolor='black', alpha=0.7, color='green')
axes[0, 1].set_xlabel('Seasonal Amplitude')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Distribution of Seasonal Amplitude')
axes[0, 1].axvline(x=0.5, color='r', linestyle='--', label='Amplitude=0.5')
axes[0, 1].axvline(x=1.0, color='orange', linestyle='--', label='Amplitude=1.0')
axes[0, 1].legend()

# Mean sales distribution (log scale)
axes[1, 0].hist(np.log10(metrics_df['mean_monthly_sales'] + 1), bins=30, 
                edgecolor='black', alpha=0.7, color='purple')
axes[1, 0].set_xlabel('Log10(Mean Monthly Sales + 1)')
axes[1, 0].set_ylabel('Frequency')
axes[1, 0].set_title('Distribution of Mean Monthly Sales (Log Scale)')

# CV vs Seasonal Amplitude scatter
scatter = axes[1, 1].scatter(metrics_df['coefficient_of_variation'], 
                             metrics_df['seasonal_amplitude'],
                             c=metrics_df['mean_monthly_sales'],
                             cmap='viridis', alpha=0.6, s=50)
axes[1, 1].set_xlabel('Coefficient of Variation')
axes[1, 1].set_ylabel('Seasonal Amplitude')
axes[1, 1].set_title('CV vs Seasonal Amplitude')
axes[1, 1].axhline(y=0.5, color='r', linestyle='--', alpha=0.5)
axes[1, 1].axvline(x=0.3, color='r', linestyle='--', alpha=0.5)
plt.colorbar(scatter, ax=axes[1, 1], label='Mean Sales')

plt.tight_layout()
plt.show()
# Out:
# ================================================================================
# DEMAND CLASSIFICATION METRICS - SUMMARY STATISTICS
# ================================================================================
#
# Coefficient of Variation (CV)
# --------------------------------------------------
# count    25228.000000
# mean         9.309223
# std         18.248589
# min          0.000000
# 25%          2.442806
# 50%          4.447310
# 75%          8.117483
# max        150.000000
# Name: coefficient_of_variation, dtype: float64
#
# Interpretation:
#   - CV < 0.3: Stable demand
#   - 0.3 <= CV < 0.7: Moderate variability
#   - CV >= 0.7: High variability
#
# ================================================================================
#
# Seasonal Amplitude
# --------------------------------------------------
# count    25228.000000
# mean        18.618447
# std         36.497179
# min          0.000000
# 25%          4.885611
# 50%          8.894620
# 75%         16.234967
# max        300.000000
# Name: seasonal_amplitude, dtype: float64
#
# Interpretation:
#   - Amplitude < 0.5: Weak seasonality
#   - 0.5 <= Amplitude < 1.0: Moderate seasonality
#   - Amplitude >= 1.0: Strong seasonality
#
# ================================================================================
#
# Mean Monthly Sales
# --------------------------------------------------
# count     25228.000000
# mean        746.077101
# std        5114.425114
# min           0.000000
# 25%          60.234163
# 50%         148.400000
# 75%         437.450000
# max      355084.400000
# Name: mean_monthly_sales, dtype: float64

# %% [markdown]
# ### Define Classification Thresholds

# %%
# Cell 6: Define Classification Thresholds
"""
Based on the statistical analysis above, define thresholds for classification.
These can be adjusted based on your specific dataset characteristics.
"""

# Define thresholds
THRESHOLDS = {
    'cv_stable': 0.3,          # CV < 0.3 indicates stable
    'cv_variable': 0.7,        # CV >= 0.7 indicates high variability
    'seasonal_weak': 0.5,      # Amplitude < 0.5 is weak seasonality
    'seasonal_strong': 1.0,    # Amplitude >= 1.0 is strong seasonality
    'low_demand': None,        # Will be set based on percentile
}

# Set low demand threshold at 25th percentile of mean sales
THRESHOLDS['low_demand'] = metrics_df['mean_monthly_sales'].quantile(0.25)

print("=" * 80)
print("CLASSIFICATION THRESHOLDS")
print("=" * 80)
print(f"\nCoefficient of Variation Thresholds:")
print(f"   Stable Demand: CV < {THRESHOLDS['cv_stable']}")
print(f"   Variable Demand: CV >= {THRESHOLDS['cv_variable']}")

print(f"\nSeasonal Amplitude Thresholds:")
print(f"   Weak Seasonality: Amplitude < {THRESHOLDS['seasonal_weak']}")
print(f"   Strong Seasonality: Amplitude >= {THRESHOLDS['seasonal_strong']}")

print(f"\nLow Demand Threshold:")
print(f"   Mean Monthly Sales < {THRESHOLDS['low_demand']:.2f}")

# Create a DataFrame for the thresholds
thresholds_df = pd.DataFrame({
    'Metric': ['CV - Stable', 'CV - Variable', 'Seasonal - Weak', 'Seasonal - Strong', 'Low Demand'],
    'Threshold': [THRESHOLDS['cv_stable'], THRESHOLDS['cv_variable'], 
                  THRESHOLDS['seasonal_weak'], THRESHOLDS['seasonal_strong'],
                  THRESHOLDS['low_demand']],
    'Interpretation': [
        'CV < threshold -> Stable demand',
        'CV >= threshold -> High variability',
        'Amplitude < threshold -> Weak seasonality',
        'Amplitude >= threshold -> Strong seasonality',
        'Mean sales < threshold -> Low demand'
    ]
})

print("\n")
print(thresholds_df.to_string(index=False))
# Out:
# ================================================================================
# CLASSIFICATION THRESHOLDS
# ================================================================================
#
# Coefficient of Variation Thresholds:
#    Stable Demand: CV < 0.3
#    Variable Demand: CV >= 0.7
#
# Seasonal Amplitude Thresholds:
#    Weak Seasonality: Amplitude < 0.5
#    Strong Seasonality: Amplitude >= 1.0
#
# Low Demand Threshold:
#    Mean Monthly Sales < 60.23
#
#
#            Metric  Threshold                               Interpretation
#       CV - Stable   0.300000              CV < threshold -> Stable demand
#     CV - Variable   0.700000          CV >= threshold -> High variability
#   Seasonal - Weak   0.500000    Amplitude < threshold -> Weak seasonality
# Seasonal - Strong   1.000000 Amplitude >= threshold -> Strong seasonality
#        Low Demand  60.234163         Mean sales < threshold -> Low demand

# %% [markdown]
# ### Classify Products into Demand Segments
# Classification Logic:
# 1. Low-demand: Mean monthly sales below threshold
# 2. Seasonal-demand: Strong seasonality (amplitude >= 1.0) OR moderate seasonality with variable CV
# 3. Stable-demand: Low CV and weak seasonality

# %%
# Cell 7: Classify Products into Demand Segments
"""
Classification Logic:
1. Low-demand: Mean monthly sales below threshold
2. Seasonal-demand: Strong seasonality (amplitude >= 1.0) OR moderate seasonality with variable CV
3. Stable-demand: Low CV and weak seasonality
"""

def classify_demand_type(row, thresholds):
    """
    Classify product based on metrics
    Priority: Low-demand > Seasonal-demand > Stable-demand
    """
    cv = row['coefficient_of_variation']
    seasonal_amp = row['seasonal_amplitude']
    mean_sales = row['mean_monthly_sales']
    
    # Check for low demand first (highest priority)
    if mean_sales < thresholds['low_demand']:
        return 'Low-demand'
    
    # Check for seasonal demand
    if seasonal_amp >= thresholds['seasonal_strong']:
        return 'Seasonal-demand'
    elif (seasonal_amp >= thresholds['seasonal_weak'] and 
          cv >= thresholds['cv_stable']):
        return 'Seasonal-demand'
    
    # Check for stable demand
    if cv < thresholds['cv_stable'] and seasonal_amp < thresholds['seasonal_weak']:
        return 'Stable-demand'
    
    # Default: if moderate variability but not clearly seasonal
    if cv < thresholds['cv_variable']:
        return 'Stable-demand'
    else:
        return 'Seasonal-demand'

# Apply classification
metrics_df['demand_type'] = metrics_df.apply(
    lambda row: classify_demand_type(row, THRESHOLDS), axis=1
)

print("Classification complete!")
print("\n" + "=" * 80)
print("DEMAND CLASSIFICATION RESULTS")
print("=" * 80)

# Count by demand type
classification_counts = metrics_df['demand_type'].value_counts()
print("\nProduct Distribution by Demand Type:")
print("-" * 50)
for demand_type, count in classification_counts.items():
    percentage = (count / len(metrics_df)) * 100
    print(f"{demand_type:20s}: {count:4d} products ({percentage:5.1f}%)")

print("\n")
metrics_df.head(10)
# Out:
# Classification complete!
#
# ================================================================================
# DEMAND CLASSIFICATION RESULTS
# ================================================================================
#
# Product Distribution by Demand Type:
# --------------------------------------------------
# Seasonal-demand     : 18909 products ( 75.0%)
# Low-demand          : 6307 products ( 25.0%)
# Stable-demand       :   12 products (  0.0%)
#                                              product               category  \
# 0    One Piece Pearl Cherry Clavicle Necklace Sui...    Fashion Accessories
# 1   1PC Motorcycle/Car New 3 LED Round Module Lig...            Motorcycles
# 2   3D Foam Brick Wall Sticker with Realistic Bri...          Home & Living
# 3                        4-Digit Sports Score Board       Sports & Outdoors
# 4   5 Pairs Korean Style Cute Socks - Trendy Ins ...          Women Clothes
# 5   60ml Oil Based Perfume for WOMEN by CENTRAL F...                 Beauty
# 6   Blind Sewing Needles Elderly Big Hole Stainle...  Hobbies & Collections
# 7   FARDLY Women's Panties Breathable Underwear W...          Women Clothes
# 8   High-Quality Raincoat Jacket and Pants Set wi...      Sports & Outdoors
# 9             Maxell Alkaline Button Cell Batteries         Home Appliances
#
#    mean_monthly_sales  seasonal_amplitude  trend_slope  max_residual_zscore  \
# 0          528.600000            7.943303   -62.339991             3.374276
# 1          935.303030            2.857529   -70.728993             3.169583
# 2        10988.589744            3.572459   -98.542156             5.091260
# 3          179.866667          255.000000     0.850315             4.394109
# 4          232.416667            6.415706   -49.393808             2.241386
# 5         9104.155556            2.947392   476.282591             5.107200
# 6          215.307692          221.000000     1.036667             4.079828
# 7          315.884615            8.224894   -29.687100             3.462448
# 8          444.807692          221.000000     2.141667             4.079828
# 9          284.244444            3.253012    41.830881             1.965622
#
#    coefficient_of_variation  n_months      demand_type
# 0                  3.971651        12  Seasonal-demand
# 1                  1.428764        12  Seasonal-demand
# 2                  1.786230        12  Seasonal-demand
# 3                127.500000        12  Seasonal-demand
# 4                  3.207853        12  Seasonal-demand
# 5                  1.473696        12  Seasonal-demand
# 6                110.500000        12  Seasonal-demand
# 7                  4.112447        12  Seasonal-demand
# 8                110.500000        12  Seasonal-demand
# 9                  1.626506        12  Seasonal-demand

# %% [markdown]
# ### Validate Classifications - Sample Products per Type
# Display sample products from each demand type to validate classifications

# %%
# Cell 8: Validate Classifications - Sample Products per Type
"""
Display sample products from each demand type to validate classifications
"""

print("=" * 80)
print("SAMPLE PRODUCTS BY DEMAND TYPE")
print("=" * 80)

for demand_type in ['Stable-demand', 'Seasonal-demand', 'Low-demand']:
    print(f"\n{'='*80}")
    print(f"{demand_type.upper()}")
    print('='*80)
    
    sample = metrics_df[metrics_df['demand_type'] == demand_type].sort_values(
        'mean_monthly_sales', ascending=False
    ).head(5)
    
    for idx, row in sample.iterrows():
        print(f"\nProduct: {row['product']}")
        print(f"  Category: {row['category']}")
        print(f"  Mean Monthly Sales: {row['mean_monthly_sales']:.2f}")
        print(f"  CV: {row['coefficient_of_variation']:.3f}")
        print(f"  Seasonal Amplitude: {row['seasonal_amplitude']:.3f}")
        print(f"  Trend Slope: {row['trend_slope']:.3f}")
# Out:
# ================================================================================
# SAMPLE PRODUCTS BY DEMAND TYPE
# ================================================================================
#
# ================================================================================
# STABLE-DEMAND
# ================================================================================
#
# Product: Assorted Color Folded Use Folding Bracket Mobile Support Cell Phone Stents phone holder
#   Category: Mobile & Gadgets
#   Mean Monthly Sales: 16716.29
#   CV: 0.274
#   Seasonal Amplitude: 0.549
#   Trend Slope: 508.184
#
# Product: 180cm//150cm140cm/90cm gabagroup Modern Korean Venetians Duo Roller Window Curtain blinds for window
#   Category: Home & Living
#   Mean Monthly Sales: 7994.04
#   CV: 0.295
#   Seasonal Amplitude: 0.590
#   Trend Slope: 171.322
#
# Product: iBaby Baby Safety Table Corner Protector Transparent Anti-Collision Angle Protection Corner Guard
#   Category: Mom & Baby
#   Mean Monthly Sales: 6055.31
#   CV: 0.250
#   Seasonal Amplitude: 0.500
#   Trend Slope: -135.625
#
# Product: OIL BASED Scents Car Hanging Diffuser Car Freshener Car Air Freshener Scent 10ml Car Scent
#   Category: Automobiles
#   Mean Monthly Sales: 5632.49
#   CV: 0.289
#   Seasonal Amplitude: 0.578
#   Trend Slope: 2.741
#
# Product: Lenbach Plus Size Waist 21-46 Women's Straight High Waist Suit Pants Wide Leg Trousers
#   Category: Women Clothes
#   Mean Monthly Sales: 5280.83
#   CV: 0.244
#   Seasonal Amplitude: 0.488
#   Trend Slope: 123.900
#
# ================================================================================
# SEASONAL-DEMAND
# ================================================================================
#
# Product: 100Pcs Powder-Free Vinyl Nitrile Gloves - Safe and Comfortable
#   Category: Home & Living
#   Mean Monthly Sales: 355084.40
#   CV: 19.527
#   Seasonal Amplitude: 39.053
#   Trend Slope: 6255.565
#
# Product: 10 Pack Facial Tissue Paper Towel 10 Pack Wipes for Baby 80pcs Organic Wipes Wet Wipes Non-Alcohol
#   Category: Mom & Baby
#   Mean Monthly Sales: 329682.54
#   CV: 20.517
#   Seasonal Amplitude: 41.033
#   Trend Slope: 5739.238
#
# Product: 4D Mask 10pcs/Pack Face-lifting Butterfly Mask 3D Protect The Nasal Cavity Face Mask
#   Category: Beauty
#   Mean Monthly Sales: 268383.02
#   CV: 0.592
#   Seasonal Amplitude: 1.185
#   Trend Slope: -27838.214
#
# Product: Thebest Organic Baby Wipes Per Pack 99% Water Hypoallergenic (Non-Alcohol-wetwipes)
#   Category: Mom & Baby
#   Mean Monthly Sales: 236051.91
#   CV: 5.427
#   Seasonal Amplitude: 10.853
#   Trend Slope: -4805.999
#
# Product: 《BiuBiu》3D Face Mask 10Pcs Korean 3D Face-lifting Butterfly More Effectively Protect Nasal
#   Category: Health
#   Mean Monthly Sales: 209358.60
#   CV: 6.692
#   Seasonal Amplitude: 13.383
#   Trend Slope: 5557.271
#
# ================================================================================
# LOW-DEMAND
# ================================================================================
#
# Product: Customized/Personalize Canvas Tote bag FLAT (SUBLIMATION PRINT)
#   Category: Women Bags
#   Mean Monthly Sales: 60.23
#   CV: 7.034
#   Seasonal Amplitude: 14.068
#   Trend Slope: -15.624
#
# Product: 1 liter 2R1H CALCIUM PLUS PRE/ PROBIOTICS MULTIVITAMINS,MINERALS AND IRON
#   Category: Home & Living
#   Mean Monthly Sales: 60.22
#   CV: 4.071
#   Seasonal Amplitude: 8.143
#   Trend Slope: -6.294
#
# Product: wedding invitation (PRINT ONLY, per piece & without envelope) min order of 10 pcs <READ DESCRIPTION>
#   Category: Home & Living
#   Mean Monthly Sales: 60.22
#   CV: 3.015
#   Seasonal Amplitude: 6.031
#   Trend Slope: 2.025
#
# Product: Japan Suntory Horoyoi - WHITE GRAPE | PEACH | GRAPE 350ML | Best Before September 30, 2023
#   Category: Food & Beverages
#   Mean Monthly Sales: 60.22
#   CV: 31.419
#   Seasonal Amplitude: 62.839
#   Trend Slope: -1.437
#
# Product: ANSEN Nano Bucket Rice Storage InsectProof MoistureProof 25KG Grain Food Storage Container
#   Category: Home & Living
#   Mean Monthly Sales: 60.20
#   CV: 37.633
#   Seasonal Amplitude: 75.265
#   Trend Slope: -1.013

# %% [markdown]
# ### Visualization 1 - Demand Type Distribution

# %%
# Cell 9: Visualization 1 - Demand Type Distribution
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Pie chart of demand types
colors = ['#2ecc71', '#f39c12', '#e74c3c']
demand_counts = metrics_df['demand_type'].value_counts()

axes[0].pie(demand_counts.values, labels=demand_counts.index, autopct='%1.1f%%',
            startangle=90, colors=colors, textprops={'fontsize': 12, 'weight': 'bold'})
axes[0].set_title('Product Distribution by Demand Type', fontsize=14, weight='bold')

# Bar chart by category
category_demand = pd.crosstab(metrics_df['category'], metrics_df['demand_type'])
category_demand.plot(kind='bar', ax=axes[1], color=colors, width=0.8)
axes[1].set_title('Demand Type Distribution by Category', fontsize=14, weight='bold')
axes[1].set_xlabel('Category', fontsize=12)
axes[1].set_ylabel('Number of Products', fontsize=12)
axes[1].legend(title='Demand Type', title_fontsize=11, fontsize=10)
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print("\nDistribution visualizations created")
# Out:
# Distribution visualizations created

# %% [markdown]
# ### Visualization 2 - Classification Scatter Plot
# Scatter plot showing CV vs Seasonal Amplitude with demand type classification

# %%
# Cell 10: Visualization 2 - Classification Scatter Plot
"""
Scatter plot showing CV vs Seasonal Amplitude with demand type classification
"""

fig, ax = plt.subplots(figsize=(14, 8))

# Create scatter plot colored by demand type
demand_types = metrics_df['demand_type'].unique()
colors_map = {'Stable-demand': '#2ecc71', 'Seasonal-demand': '#f39c12', 'Low-demand': '#e74c3c'}

for demand_type in demand_types:
    subset = metrics_df[metrics_df['demand_type'] == demand_type]
    ax.scatter(subset['coefficient_of_variation'], 
               subset['seasonal_amplitude'],
               c=colors_map[demand_type],
               label=demand_type,
               alpha=0.6,
               s=100,
               edgecolors='black',
               linewidth=0.5)

# Add threshold lines
ax.axhline(y=THRESHOLDS['seasonal_weak'], color='gray', linestyle='--', 
           alpha=0.5, label=f'Seasonal threshold = {THRESHOLDS["seasonal_weak"]}')
ax.axhline(y=THRESHOLDS['seasonal_strong'], color='gray', linestyle='--', alpha=0.5)
ax.axvline(x=THRESHOLDS['cv_stable'], color='gray', linestyle='--', 
           alpha=0.5, label=f'CV threshold = {THRESHOLDS["cv_stable"]}')
ax.axvline(x=THRESHOLDS['cv_variable'], color='gray', linestyle='--', alpha=0.5)

ax.set_xlabel('Coefficient of Variation (CV)', fontsize=12, weight='bold')
ax.set_ylabel('Seasonal Amplitude', fontsize=12, weight='bold')
ax.set_title('Product Classification: CV vs Seasonal Amplitude', fontsize=14, weight='bold')
ax.legend(fontsize=10, loc='best')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("Classification scatter plot created")
# Out:
# Classification scatter plot created

# %% [markdown]
# ### Visualization 3 - Heatmap of Category vs Demand Type
# Heatmap showing the relationship between product categories and demand types

# %%
# Cell 11: Visualization 3 - Heatmap of Category vs Demand Type
"""
Heatmap showing the relationship between product categories and demand types
"""

# Create contingency table
category_demand_crosstab = pd.crosstab(
    metrics_df['category'], 
    metrics_df['demand_type'],
    normalize='index'  # Normalize by row (category)
) * 100  # Convert to percentage

# Create heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(category_demand_crosstab, annot=True, fmt='.1f', cmap='YlOrRd',
            cbar_kws={'label': 'Percentage (%)'}, linewidths=0.5, linecolor='gray')
plt.title('Demand Type Distribution by Category (% within each category)', 
          fontsize=14, weight='bold', pad=20)
plt.xlabel('Demand Type', fontsize=12, weight='bold')
plt.ylabel('Category', fontsize=12, weight='bold')
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

print("Category vs Demand Type heatmap created")
# Out:
# Category vs Demand Type heatmap created

# %% [markdown]
# ### Summary Statistics by Demand Type
# Comprehensive statistics table for each demand type

# %%
# Cell 12: Summary Statistics by Demand Type
"""
Comprehensive statistics table for each demand type
"""

print("=" * 80)
print("DETAILED STATISTICS BY DEMAND TYPE")
print("=" * 80)

summary_stats = metrics_df.groupby('demand_type').agg({
    'mean_monthly_sales': ['mean', 'median', 'std', 'min', 'max'],
    'coefficient_of_variation': ['mean', 'median'],
    'seasonal_amplitude': ['mean', 'median'],
    'trend_slope': ['mean', 'median'],
    'product': 'count'
}).round(3)

summary_stats.columns = ['_'.join(col).strip() for col in summary_stats.columns.values]
summary_stats = summary_stats.rename(columns={'product_count': 'n_products'})

print("\n")
print(summary_stats.to_string())

# Additional insights
print("\n" + "="*80)
print("KEY INSIGHTS")
print("="*80)

for demand_type in metrics_df['demand_type'].unique():
    subset = metrics_df[metrics_df['demand_type'] == demand_type]
    print(f"\n{demand_type}:")
    print(f"   Products: {len(subset)} ({len(subset)/len(metrics_df)*100:.1f}%)")
    print(f"   Avg Monthly Sales: {subset['mean_monthly_sales'].mean():.2f}")
    print(f"   Avg CV: {subset['coefficient_of_variation'].mean():.3f}")
    print(f"   Avg Seasonal Amplitude: {subset['seasonal_amplitude'].mean():.3f}")
# Out:
# ================================================================================
# DETAILED STATISTICS BY DEMAND TYPE
# ================================================================================
#
#
#                  mean_monthly_sales_mean  mean_monthly_sales_median  mean_monthly_sales_std  mean_monthly_sales_min  mean_monthly_sales_max  coefficient_of_variation_mean  coefficient_of_variation_median  seasonal_amplitude_mean  seasonal_amplitude_median  trend_slope_mean  trend_slope_median  n_products
# demand_type
# Low-demand                        30.145                     32.778                  18.183                   0.000                  60.231                          9.510                            4.887                   19.021                      9.774            -1.923              -1.567        6307
# Seasonal-demand                  982.113                    240.022                5886.456                  60.235              355084.400                          9.248                            4.071                   18.496                      8.143           -11.784              -3.938       18909
# Stable-demand                   5093.809                   3831.444                4124.911                1805.933               16716.289                          0.260                            0.262                    0.521                      0.524           109.213              86.040          12
#
# ================================================================================
# KEY INSIGHTS
# ================================================================================
#
# Seasonal-demand:
#    Products: 18909 (75.0%)
#    Avg Monthly Sales: 982.11
#    Avg CV: 9.248
#    Avg Seasonal Amplitude: 18.496
#
# Low-demand:
#    Products: 6307 (25.0%)
#    Avg Monthly Sales: 30.15
#    Avg CV: 9.510
#    Avg Seasonal Amplitude: 19.021
#
# Stable-demand:
#    Products: 12 (0.0%)
#    Avg Monthly Sales: 5093.81
#    Avg CV: 0.260
#    Avg Seasonal Amplitude: 0.521

# %% [markdown]
# ### Validation Check - Classification Quality
# Perform quality checks on the classification

# %%
# Cell 13: Validation Check - Classification Quality
"""
Perform quality checks on the classification
"""

print("=" * 80)
print("CLASSIFICATION QUALITY CHECKS")
print("=" * 80)

# Check 1: Verify stable products have low CV
stable_products = metrics_df[metrics_df['demand_type'] == 'Stable-demand']
stable_high_cv = stable_products[stable_products['coefficient_of_variation'] > THRESHOLDS['cv_variable']]

print(f"\nCheck 1: Stable products with unexpectedly high CV")
print(f"   Found: {len(stable_high_cv)} products")
if len(stable_high_cv) > 0:
    print(f"   These products may need review:")
    print(stable_high_cv[['product', 'coefficient_of_variation', 'seasonal_amplitude']].head())

# Check 2: Verify seasonal products have high amplitude
seasonal_products = metrics_df[metrics_df['demand_type'] == 'Seasonal-demand']
seasonal_low_amp = seasonal_products[seasonal_products['seasonal_amplitude'] < THRESHOLDS['seasonal_weak']]

print(f"\nCheck 2: Seasonal products with low seasonal amplitude")
print(f"   Found: {len(seasonal_low_amp)} products")
if len(seasonal_low_amp) > 0:
    print(f"   These were classified as seasonal due to high CV:")
    print(seasonal_low_amp[['product', 'coefficient_of_variation', 'seasonal_amplitude']].head())

# Check 3: Distribution check
print(f"\nCheck 3: Distribution balance")
print(f"   Target: No single category should dominate (>70%)")
print(f"   Results:")
for demand_type, count in metrics_df['demand_type'].value_counts().items():
    pct = count / len(metrics_df) * 100
    status = "WARNING" if pct > 70 else "PASS"
    print(f"   [{status}] {demand_type}: {pct:.1f}%")

# Check 4: Missing values
print(f"\nCheck 4: Missing or invalid values")
missing_cv = metrics_df['coefficient_of_variation'].isna().sum()
print(f"   Missing CV values: {missing_cv}")
print(f"   All products classified: {metrics_df['demand_type'].notna().all()}")

print("\n" + "=" * 80)
print("QUALITY CHECKS COMPLETE")
print("=" * 80)
# Out:
# ================================================================================
# CLASSIFICATION QUALITY CHECKS
# ================================================================================
#
# Check 1: Stable products with unexpectedly high CV
#    Found: 0 products
#
# Check 2: Seasonal products with low seasonal amplitude
#    Found: 0 products
#
# Check 3: Distribution balance
#    Target: No single category should dominate (>70%)
#    Results:
#    [WARNING] Seasonal-demand: 75.0%
#    [PASS] Low-demand: 25.0%
#    [PASS] Stable-demand: 0.0%
#
# Check 4: Missing or invalid values
#    Missing CV values: 0
#    All products classified: True
#
# ================================================================================
# QUALITY CHECKS COMPLETE
# ================================================================================

# %% [markdown]
# ### Interactive Product Lookup
# Function to look up classification details for specific products

# %%
# Cell 14: Interactive Product Lookup
"""
Function to look up classification details for specific products
"""

def lookup_product(product_name):
    """
    Look up classification details for a specific product
    """
    result = metrics_df[metrics_df['product'].str.contains(product_name, case=False)]
    
    if len(result) == 0:
        print(f"No products found matching '{product_name}'")
        return
    
    print("=" * 80)
    print(f"SEARCH RESULTS FOR: '{product_name}'")
    print("=" * 80)
    
    for idx, row in result.iterrows():
        print(f"\nProduct: {row['product']}")
        print(f"   Category: {row['category']}")
        print(f"   Demand Type: {row['demand_type']}")
        print(f"\n   Metrics:")
        print(f"   - Mean Monthly Sales: {row['mean_monthly_sales']:.2f}")
        print(f"   - Coefficient of Variation: {row['coefficient_of_variation']:.3f}")
        print(f"   - Seasonal Amplitude: {row['seasonal_amplitude']:.3f}")
        print(f"   - Trend Slope: {row['trend_slope']:.4f}")
        print(f"\n   Interpretation:")
        
        if row['demand_type'] == 'Stable-demand':
            print("   - Consistent, predictable demand")
            print("   - Low inventory risk")
        elif row['demand_type'] == 'Seasonal-demand':
            print("   - Requires seasonal inventory planning")
            print("   - Monitor peak periods closely")
        else:
            print("   - Low overall demand")
            print("   - Consider SKU rationalization")
        print("-" * 80)

# Example usage
print("Example: Lookup products containing 'necklace'\n")
lookup_product('necklace')
# Out:
# Example: Lookup products containing 'necklace'
#
# ================================================================================
# SEARCH RESULTS FOR: 'necklace'
# ================================================================================
#
# Product:   One Piece Pearl Cherry Clavicle Necklace Suitable for Women Daily Wear
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 528.60
#    - Coefficient of Variation: 3.972
#    - Seasonal Amplitude: 7.943
#    - Trend Slope: -62.3400
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 0.5/0.8/1.0/1.5/2.0mm black/brown cotton wax thread for DIY necklace wax rope
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 531.27
#    - Coefficient of Variation: 2.480
#    - Seasonal Amplitude: 4.959
#    - Trend Slope: -33.8314
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 10 Fashion Accessories Live Link maohuo Beads Bracelet necklace Pendant Factory Direct Sales  直播链接 私拍无效
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 397.19
#    - Coefficient of Variation: 2.633
#    - Seasonal Amplitude: 5.267
#    - Trend Slope: -85.4211
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 10/50m 0.8mm Stretch Elastic Cord For Bracelets Necklace Nylon Beading String Thread Diy Jewelry
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 817.12
#    - Coefficient of Variation: 1.398
#    - Seasonal Amplitude: 2.795
#    - Trend Slope: -20.3597
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 100 Fashion Accessories Live Link Beads Bracelet necklace Pendant Factory Direct Sales do not place orders without authorization
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 920.48
#    - Coefficient of Variation: 1.995
#    - Seasonal Amplitude: 3.989
#    - Trend Slope: -200.2466
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 100pcs Letter beads 4x7 mm letter beads acrylic round 26 English letter beads multi-color peach heart-shaped spacer beads, used for bracelet necklace jewelry making
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 32.47
#    - Coefficient of Variation: 13.372
#    - Seasonal Amplitude: 26.744
#    - Trend Slope: -1.5422
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: 18K Gold 26 Letter Snake Chain Necklace Pendant Classic Fashion Men's and Women's Letter Necklace Jewelry Wholesale
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 80.73
#    - Coefficient of Variation: 34.910
#    - Seasonal Amplitude: 69.821
#    - Trend Slope: -1.8004
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 18K Gold Zircon Initial Necklace Floral Letter Name Snake Chain for Women Unisex Fashion Jewelry Accessories
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 114.15
#    - Coefficient of Variation: 9.654
#    - Seasonal Amplitude: 19.308
#    - Trend Slope: -19.7378
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 18K Golden Stainless Steel Benedict San Benito Mama Mary Faith Cross necklace（free box)
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 129.02
#    - Coefficient of Variation: 5.871
#    - Seasonal Amplitude: 11.742
#    - Trend Slope: -5.5039
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 18k Gold Cubic Zirconia Birthstone Heart Barbie Pendant Necklace Accessories Plus Premium Bo
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 12.09
#    - Coefficient of Variation: 4.472
#    - Seasonal Amplitude: 8.944
#    - Trend Slope: -1.7561
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: 1PCS eye Tribe necklace#more design#random design
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 93.65
#    - Coefficient of Variation: 34.677
#    - Seasonal Amplitude: 69.355
#    - Trend Slope: -1.6979
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 1Pc Small 12*14mm A-Z Letter Pendant Charms Enamel Alphabet Initial Letter Handmade Pendants for Diy Bracelet Necklace
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 24.69
#    - Coefficient of Variation: 4.605
#    - Seasonal Amplitude: 9.210
#    - Trend Slope: -3.4429
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: 24pcs/ 12pcs Gift Box for Accessories Jewelry Ring / Necklace / Bracelet
#    Category: Stationery
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 767.16
#    - Coefficient of Variation: 1.425
#    - Seasonal Amplitude: 2.850
#    - Trend Slope: -70.6954
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 35cm/7-8mm ,8-9mm Authentic Fresh Water Pearl Beads Loose Beads For Jewelry Making DIY Bracelet Necklace
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 72.51
#    - Coefficient of Variation: 8.891
#    - Seasonal Amplitude: 17.783
#    - Trend Slope: -1.2906
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 4/6MM Multi-Color Plastic ABS Round Imitation Pearl Loose Beads With Holes DIY Art Necklace Accessories
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 186.87
#    - Coefficient of Variation: 8.117
#    - Seasonal Amplitude: 16.235
#    - Trend Slope: -0.5512
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 4pcs/set High Quality Hawaiian Flowers Necklace Fancy Dress Wedding Decorations Headband Garland Par
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 112.34
#    - Coefficient of Variation: 10.094
#    - Seasonal Amplitude: 20.189
#    - Trend Slope: 8.2057
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 5 Piece Women Watch Gift Set with Bracelet Necklace Earrings Rings with Diamonds Metal Straps Watches for Ladies no box
#    Category: Watches
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 399.30
#    - Coefficient of Variation: 20.513
#    - Seasonal Amplitude: 41.026
#    - Trend Slope: 13.7543
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: A multi-wear four-leaf clover titanium steel necklace women's light luxury love clavicle chain ins trend necklace
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 44.96
#    - Coefficient of Variation: 5.364
#    - Seasonal Amplitude: 10.728
#    - Trend Slope: -5.1811
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: ADK High Quality Letter Necklace Sea Shell Pendan Alphabet Personalize Stainless Steel Pendant Necklaces for woman man
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 74.70
#    - Coefficient of Variation: 5.741
#    - Seasonal Amplitude: 11.482
#    - Trend Slope: -5.2794
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Alcohol Spray Bottle 10ml Necklace FREE Lanyard Portable Alcohol Sprayer Necklace Holder Included
#    Category: Travel & Luggage
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 1870.05
#    - Coefficient of Variation: 2.188
#    - Seasonal Amplitude: 4.375
#    - Trend Slope: -188.6788
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: BALFE JEWELRY BOX FOR BANGLE ,BRACELET ,NECKLACE ,EARRING and RING
#    Category: Home & Living
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 50.76
#    - Coefficient of Variation: 3.600
#    - Seasonal Amplitude: 7.201
#    - Trend Slope: -7.1418
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Bangkok10k Piyao Small Necklace 18inch Boxchain Twistedchain
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 272.00
#    - Coefficient of Variation: 1.141
#    - Seasonal Amplitude: 2.281
#    - Trend Slope: -28.2060
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Beryl❤Mask Lanyard Mask Chain Anti-lost Mask Lanyard Mask Necklace Holder Adult Non-marking Ear Hooks Two Hooks
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 403.11
#    - Coefficient of Variation: 4.071
#    - Seasonal Amplitude: 8.143
#    - Trend Slope: -42.1312
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Black bead mosaic clavicle chain Diablo High Street diamond spider pendant round bead necklace for men and women.
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 14.16
#    - Coefficient of Variation: 4.472
#    - Seasonal Amplitude: 8.944
#    - Trend Slope: -2.0563
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Blessed Evil Eye Necklace Women Lucky Devil Eye Pendant Clavicle Chain Gift Jewelry
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 308.66
#    - Coefficient of Variation: 3.820
#    - Seasonal Amplitude: 7.640
#    - Trend Slope: -18.2407
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Boho Handmade Tassel Necklace Earring Set 2022 Trend Sweater Chain Accessories Vintage Ethnic Fringe Dangle Earrings for Women
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 97.84
#    - Coefficient of Variation: 6.529
#    - Seasonal Amplitude: 13.058
#    - Trend Slope: -3.7198
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: CXFASHION Black Metal English Letter Pendant Necklace Ladies A-Z For Gift
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 915.68
#    - Coefficient of Variation: 2.581
#    - Seasonal Amplitude: 5.161
#    - Trend Slope: -114.0387
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Cat or Dog ID Tag Free Engraving Dog Collar Pet Charm Pet Name Pendant Bone Necklace Collar Puppy Cat Collar Accessory
#    Category: Pets
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 104.27
#    - Coefficient of Variation: 8.117
#    - Seasonal Amplitude: 16.235
#    - Trend Slope: -0.3076
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Cheapest Hawaiian Puka necklace beach necklace accessories made from Clam Shell
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 139.67
#    - Coefficient of Variation: 8.117
#    - Seasonal Amplitude: 16.235
#    - Trend Slope: -0.4120
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Custom ID Name Tag Cat Kitten Collar Bell Necklace Safety Reflective Nylon  Personalized Engraved Nameplate Dog Tag
#    Category: Pets
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 77.00
#    - Coefficient of Variation: 10.647
#    - Seasonal Amplitude: 21.293
#    - Trend Slope: 4.4504
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: DM jewelry 14K Saudi Gold Plated Jewelry Set 3in1 necklace earring adjustable ring
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 29.80
#    - Coefficient of Variation: 5.170
#    - Seasonal Amplitude: 10.339
#    - Trend Slope: -4.0988
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: DREJEW Diamond-Studded Water Drop Tassel Necklace & Earrings Set - Elegant Silver Clavicle Chain Accessories for Women
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 58.30
#    - Coefficient of Variation: 6.615
#    - Seasonal Amplitude: 13.231
#    - Trend Slope: -15.0013
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: DUSE 18k Gold Diamond Necklace Light Luxury Design Fashion Shiny Micro Inlaid Zircon Pendant Gold Plated Stainless Steel For Women Clavicle Choker
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 15.76
#    - Coefficient of Variation: 32.944
#    - Seasonal Amplitude: 65.887
#    - Trend Slope: -0.2972
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: DUSE 18k Gold Temperament Planet Pearl Necklace Girls Personality Titanium Steel Clavicle Accessories For Women
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 15.79
#    - Coefficient of Variation: 32.944
#    - Seasonal Amplitude: 65.887
#    - Trend Slope: -0.2976
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Elegant Pearl Heart Butterfly Necklaces for Women Crystal Choker Chain Necklace Accessories Jewelry
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 169.76
#    - Coefficient of Variation: 28.754
#    - Seasonal Amplitude: 57.508
#    - Trend Slope: -18.7963
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Elegant Tulip Necklace For Women Niche Design High-end All-match Gentle Girlfriends Clavicle Chain Female HO
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 284.63
#    - Coefficient of Variation: 3.262
#    - Seasonal Amplitude: 6.524
#    - Trend Slope: -43.8037
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Elegant White Imitation Pearl Necklace – Unisex Jewelry, 40cm
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 166.76
#    - Coefficient of Variation: 3.118
#    - Seasonal Amplitude: 6.235
#    - Trend Slope: 13.6367
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Elegent Camellia Jewelry Set for Women Pearl Stud Earrings Necklace Fashion Jewelry Set Accessories
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 238.10
#    - Coefficient of Variation: 6.247
#    - Seasonal Amplitude: 12.494
#    - Trend Slope: 27.2143
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Evil Eye Cat Eye Doll Eye Necklace for Men and Women
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 96.51
#    - Coefficient of Variation: 4.749
#    - Seasonal Amplitude: 9.498
#    - Trend Slope: -13.1975
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Evil Eyes Doll Eyes Cat Eyes Necklace for Men and Women
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 42.05
#    - Coefficient of Variation: 33.810
#    - Seasonal Amplitude: 67.621
#    - Trend Slope: -0.7773
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Fashion Double Heart Necklace Ladies Valentine's Day Gift Girlfriend Gift Pendant Gold Silver 925 Sterling Silver Necklace Women Shiny Double Heart Love Heart Clavicle Chain Zircon Simple Fashion Ladies Friendship Necklace Party Gift Collar Jewelry
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 63.27
#    - Coefficient of Variation: 2.625
#    - Seasonal Amplitude: 5.251
#    - Trend Slope: 3.1954
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Fashion Face Mask Lanyard Bead Chain Holder Cord Necklace Eyeglass Strap Black Rope Adjustable
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 32.36
#    - Coefficient of Variation: 38.488
#    - Seasonal Amplitude: 76.976
#    - Trend Slope: -0.5349
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Fashion High Quality Magnetic Lobster Buckle Accessories Necklace Anti-Lost Cord M60095
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 18.96
#    - Coefficient of Variation: 4.472
#    - Seasonal Amplitude: 8.944
#    - Trend Slope: -2.7536
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Fashion Letter Necklace/Stainless Steel Shell Letter Pendant Necklace/Necklace for Women SP
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 1318.11
#    - Coefficient of Variation: 0.726
#    - Seasonal Amplitude: 1.452
#    - Trend Slope: -124.5370
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Fashion Round Charm Necklace Elegant Luxury Retro Chain Choker Women Jewelry Accessories perfectqueen
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 53.75
#    - Coefficient of Variation: 8.172
#    - Seasonal Amplitude: 16.344
#    - Trend Slope: -4.0623
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Fashion Tulip Gold Lock Bone Chain Necklace Women's Jewelry Wholesale
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 237.97
#    - Coefficient of Variation: 2.802
#    - Seasonal Amplitude: 5.604
#    - Trend Slope: -48.0696
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Fashion Vintage Elegant White Glass Imitation Freshwater Pearl Necklaces Women Jewerly
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 235.46
#    - Coefficient of Variation: 3.064
#    - Seasonal Amplitude: 6.128
#    - Trend Slope: -1.1261
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Flannel Portable Jewelry Travel Box Necklace Earring Ring Women High End Luxury Storage Box Organize
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 177.53
#    - Coefficient of Variation: 134.375
#    - Seasonal Amplitude: 268.750
#    - Trend Slope: 0.7205
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Flash Sale ITALY 92.5% SILVER LOCK for necklace for bracelet (lobster lock/mosquiton lock)
#    Category: Baby & Kids Fashion
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 6.38
#    - Coefficient of Variation: 4.266
#    - Seasonal Amplitude: 8.532
#    - Trend Slope: -0.9368
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: For you 18K Gold Eirin Pendant Necklace With Box Jewelry For Women Accessories Fashion Gift
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 90.07
#    - Coefficient of Variation: 6.698
#    - Seasonal Amplitude: 13.395
#    - Trend Slope: -19.0177
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Glow In the Dark Luminous Natural Stone Heart Star Pendant Necklace Jewelry Gift
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 13.60
#    - Coefficient of Variation: 5.688
#    - Seasonal Amplitude: 11.377
#    - Trend Slope: -1.4373
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Gold Alloy Clavicle Short Simple Necklace Women's Short Wave Chain Clavicle Women Jewelry Personality A HELLO GIRL
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 11.78
#    - Coefficient of Variation: 4.472
#    - Seasonal Amplitude: 8.944
#    - Trend Slope: -1.7109
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Gold Necklace for Unisex Stainless Hypoallergenic Letter SnakeChain Non Tarnish alphabet Necklace
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 226.39
#    - Coefficient of Variation: 2.513
#    - Seasonal Amplitude: 5.026
#    - Trend Slope: -28.5760
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Hawaiian Flower Lace Garland Necklace Fancy Dress Party Hawaii Beach Fun Unisex
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 946.60
#    - Coefficient of Variation: 2.394
#    - Seasonal Amplitude: 4.788
#    - Trend Slope: -35.0757
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Hawaiian Flower lace  Garland Necklace Unisex
#    Category: Baby & Kids Fashion
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 83.67
#    - Coefficient of Variation: 8.891
#    - Seasonal Amplitude: 17.783
#    - Trend Slope: -1.4892
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Infinity Heart Necklace Series - with free box 18K Gold Tala Inspired
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 68.62
#    - Coefficient of Variation: 8.891
#    - Seasonal Amplitude: 17.783
#    - Trend Slope: -1.2214
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: JS&CO jewelry 925 silver 3in1 Jewelry Set Necklace Earrings Bracelet set-70
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 37.49
#    - Coefficient of Variation: 4.605
#    - Seasonal Amplitude: 9.210
#    - Trend Slope: -5.2279
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Jewellery Box Travel Organizer Mini PU Leather Storage for Rings Earrings Necklace Jewelry Box
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 435.38
#    - Coefficient of Variation: 2.909
#    - Seasonal Amplitude: 5.817
#    - Trend Slope: 28.3155
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Jewelry Gift Box for Necklace Sets Rings and Earrings Unisex Perfect for Gifting Versatile and Conve
#    Category: Stationery
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 1497.73
#    - Coefficient of Variation: 0.301
#    - Seasonal Amplitude: 0.602
#    - Trend Slope: -110.6969
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Korean Fashion Elegant lover Necklace Heart Shape Necklace Couple Promise Necklace Bracelet E
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 123.07
#    - Coefficient of Variation: 4.885
#    - Seasonal Amplitude: 9.769
#    - Trend Slope: -0.4950
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Kwintas Stainless Steel Necklace For Women Vintage Butterfly Pendant Four Leaf Clover Necklace Non Tarnish Chain Choker Accessories Jewelry
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 342.33
#    - Coefficient of Variation: 3.283
#    - Seasonal Amplitude: 6.565
#    - Trend Slope: 13.4370
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: LAJ- Stainless Gold Snake Chain Necklace 16, 18, 20, 22, 24 inches Available
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 553.58
#    - Coefficient of Variation: 1.693
#    - Seasonal Amplitude: 3.386
#    - Trend Slope: -10.3302
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: LS jewelry 24K Bangkok Gold Heart Key Necklace NZ1205+C1002
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 49.84
#    - Coefficient of Variation: 7.116
#    - Seasonal Amplitude: 14.233
#    - Trend Slope: 4.2715
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: LS jewelry Stainless Gold Necklace Letters SnakeChain for unisex 2591n
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 272.59
#    - Coefficient of Variation: 1.790
#    - Seasonal Amplitude: 3.579
#    - Trend Slope: -20.9191
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Lanyard Silicone Ring (Elastic) Lanyard Relx / Shift / Yooz Universal Spot Necklace Wholesale vape
#    Category: Home Appliances
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 412.58
#    - Coefficient of Variation: 3.084
#    - Seasonal Amplitude: 6.168
#    - Trend Slope: -26.0556
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Lanyard wholesale Relx/yooz/shift universal silicone ring (silicone ring with elasticity) necklace
#    Category: Home Appliances
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 875.93
#    - Coefficient of Variation: 1.390
#    - Seasonal Amplitude: 2.780
#    - Trend Slope: -66.9290
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Lifan Natural sakura tourmaline garnet ghost wax crystal bracelet ring necklace sweater chain car hang
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 511.58
#    - Coefficient of Variation: 1.288
#    - Seasonal Amplitude: 2.576
#    - Trend Slope: -43.4337
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Live Link!!Jade Crystal Jewelry Live Link, Contact Customer Service Before Shipment, Self-Service Order!!Natural Jadeite A Goods Pendant Bracelet Bracelet Necklace Ear Hook Earrings Earrings Mobile Phone Bag Hanging Ring Ring Accessories DIY
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 50.23
#    - Coefficient of Variation: 4.893
#    - Seasonal Amplitude: 9.785
#    - Trend Slope: -7.9738
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Lovito Casual Plain Chain Texture Metal Choker Necklaces For Women L18M132
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 54.88
#    - Coefficient of Variation: 5.006
#    - Seasonal Amplitude: 10.011
#    - Trend Slope: -8.1197
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Lovito Women Casual Necklaces Key Shape Rhinestone Necklaces L18M134 (Gold)
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 226.88
#    - Coefficient of Variation: 1.990
#    - Seasonal Amplitude: 3.980
#    - Trend Slope: 9.3876
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Luxury Accessories Jewelry Organizer Box for Engagement Wedding Anniversary Gift for RING Necklace
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 573.56
#    - Coefficient of Variation: 3.537
#    - Seasonal Amplitude: 7.074
#    - Trend Slope: 69.1906
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Mask Hanging Rope Adjustable Traceless Necklace Chain Pearl Eyeglasses Lanyards CM
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 124.62
#    - Coefficient of Variation: 1.985
#    - Seasonal Amplitude: 3.969
#    - Trend Slope: -16.0737
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Mask chain Magnetic mask chain mask adapter 2 in 1 hijab mask extension mask extender Necklace Korean Muka Mask Strap Headloop
#    Category: Home & Living
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 44.69
#    - Coefficient of Variation: 13.372
#    - Seasonal Amplitude: 26.744
#    - Trend Slope: -2.1228
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Men's fashion trend casual accessories jewelry 925 Silver Pendant Necklace for men
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 36.76
#    - Coefficient of Variation: 38.488
#    - Seasonal Amplitude: 76.976
#    - Trend Slope: -0.6077
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Men's/Women's Fashion Glossy Jesus Cross Pendant Necklace Silver Gold Black
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 250.42
#    - Coefficient of Variation: 10.647
#    - Seasonal Amplitude: 21.293
#    - Trend Slope: 14.4738
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Mikana 18k Gold Plated Miyumi Pendant Necklace Accessories Jewelry For Women Jewelries Choker
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 167.89
#    - Coefficient of Variation: 4.071
#    - Seasonal Amplitude: 8.143
#    - Trend Slope: -17.5469
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Mikana 18k Rose Gold Plated Yuka Layered Pendant Necklace Accessories Jewelry For Women Jewelries
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 69.82
#    - Coefficient of Variation: 4.071
#    - Seasonal Amplitude: 8.143
#    - Trend Slope: -7.2975
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Mikana Twofer 18k Gold Plated Tomomi Pendant Necklace Accessories Jewelry For Women Gift Heart
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 10.20
#    - Coefficient of Variation: 4.266
#    - Seasonal Amplitude: 8.532
#    - Trend Slope: -1.4982
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Mini Plastic Storage Transparent Jewelry Earing Container Storage Small Box Cube Rings Necklace
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 62.69
#    - Coefficient of Variation: 2.672
#    - Seasonal Amplitude: 5.344
#    - Trend Slope: -7.9510
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Mumu Jl01 High Quality Necklace Stainless Steel Snake Chain Necklaces
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 238.67
#    - Coefficient of Variation: 2.174
#    - Seasonal Amplitude: 4.347
#    - Trend Slope: -16.1330
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Natural sakura tourmaline garnet ghost wax crystal bracelet ring necklace sweater chain car hang
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 398.07
#    - Coefficient of Variation: 1.217
#    - Seasonal Amplitude: 2.433
#    - Trend Slope: -32.5676
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Necklace Diamond Jewelry Shoe chamrs Jibbit Charm Set  Decoration
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 263.44
#    - Coefficient of Variation: 1.589
#    - Seasonal Amplitude: 3.177
#    - Trend Slope: -21.0245
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Necklace Men's Sports Outdoor Camping Survival Tools Polkunk Domineering Domineering Pendant
#    Category: Sports & Outdoors
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 132.31
#    - Coefficient of Variation: 13.189
#    - Seasonal Amplitude: 26.378
#    - Trend Slope: -11.0431
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Neutrals.mnl - (Non fading) Pear shape Necklace (NEW & IMPROVED PENDANT and CHAIN)
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 103.39
#    - Coefficient of Variation: 14.576
#    - Seasonal Amplitude: 29.151
#    - Trend Slope: -0.7749
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Nine-Tailed Fox Pendant Necklace with Gemstones
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 1634.92
#    - Coefficient of Variation: 12.933
#    - Seasonal Amplitude: 25.866
#    - Trend Slope: 215.0499
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Ocean Heart Crystal Necklace - Blue Love Design in Titanium Steel, Stylish Fashion Accessory for Women chain necklace
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 0.00
#    - Coefficient of Variation: 0.000
#    - Seasonal Amplitude: 0.000
#    - Trend Slope: 0.0000
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Paper Clip Chain Necklace & Bracelet - Simple Elegant Hypoallergenic Stainless Steel
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 472.53
#    - Coefficient of Variation: 4.278
#    - Seasonal Amplitude: 8.557
#    - Trend Slope: 5.8554
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Paper Clip Chain Necklace and Bracelet Simple Elegant Hypo-allergenic Stainless Steel Non Rust
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 40.84
#    - Coefficient of Variation: 13.372
#    - Seasonal Amplitude: 26.744
#    - Trend Slope: -1.9401
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Pearl Necklace Earphone 3.5mm In-Ear Headset Pink Rhinestone Necklace Jewelry Beads Earphones With Mic For Brithday Girls Gifts
#    Category: Audio
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 192.78
#    - Coefficient of Variation: 3.831
#    - Seasonal Amplitude: 7.662
#    - Trend Slope: -11.0286
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Personalized Name Pendant in Fantasia Chain Necklace (Hypoallergenic & Non-Tarnishing)
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 495.89
#    - Coefficient of Variation: 5.282
#    - Seasonal Amplitude: 10.564
#    - Trend Slope: -23.5532
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Pet Glowing Collars with Bells Glow at Night Dogs Cats Necklace Light Luminous Neck Ring Accessories
#    Category: Pets
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 264.76
#    - Coefficient of Variation: 4.011
#    - Seasonal Amplitude: 8.023
#    - Trend Slope: -3.6520
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Red lucky fish Pendant Koi Necklaces For Women Jewelry Cute Accessories
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 658.50
#    - Coefficient of Variation: 1.893
#    - Seasonal Amplitude: 3.786
#    - Trend Slope: -65.2625
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Religious Catholic Jesus Wooden Cross Pendant Necklaces Adjustable Rope Chains
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 56.44
#    - Coefficient of Variation: 8.891
#    - Seasonal Amplitude: 17.783
#    - Trend Slope: -1.0046
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: SILK JEWELRY, NECKLACE, BRACELETT AND ACCESSORIES POUCH, FOR SOAP,  SMALL ITEM GIFT POUCH-WHOLESALE
#    Category: Women Bags
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 203.49
#    - Coefficient of Variation: 2.519
#    - Seasonal Amplitude: 5.038
#    - Trend Slope: -18.4904
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Safety Hanging Neck Strap Unviersal Anti Lost Necklace Rope Mobile Phone IPhone Samsung Lanyard
#    Category: Mobile & Gadgets
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 133.45
#    - Coefficient of Variation: 2.809
#    - Seasonal Amplitude: 5.617
#    - Trend Slope: -20.5979
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Simple Pearl Choker Necklace for Women Elegant Women Jewerly Accessories CM
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 184.11
#    - Coefficient of Variation: 2.747
#    - Seasonal Amplitude: 5.493
#    - Trend Slope: -25.6509
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: St. Kunkka 3/4/6/8mm  Multi-Color Plastic ABS Faux Pearl Beads Imitation Pearl Beads Acrylic Colored Pearls Loose Necklace Bracelet Diy
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 80.78
#    - Coefficient of Variation: 11.132
#    - Seasonal Amplitude: 22.264
#    - Trend Slope: -0.7745
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: St. kunkka 20-40pcs Sets/Bag Crystal Colorful Charm Tulip Flower Beads Glass Flower Loose Beads DIY Bracelet Necklace Jewelry Manufacturing
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 451.28
#    - Coefficient of Variation: 1.551
#    - Seasonal Amplitude: 3.102
#    - Trend Slope: -99.7171
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: St. kunkka 5PCS Double Hole Butterfly Pendant Alloy Enamel Pendant Earrings Necklace Bracelet DIY Jewelry Making
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 1254.59
#    - Coefficient of Variation: 1.495
#    - Seasonal Amplitude: 2.989
#    - Trend Slope: -105.9265
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# ...
#
#    Metrics:
#    - Mean Monthly Sales: 87.48
#    - Coefficient of Variation: 3.064
#    - Seasonal Amplitude: 6.129
#    - Trend Slope: -12.9164
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: TBK 18K japan cuban Stainless Cross mamamary st.benidict necklace for men hypoallergenic kwintas
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 92.36
#    - Coefficient of Variation: 4.698
#    - Seasonal Amplitude: 9.396
#    - Trend Slope: -6.5852
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: TBK 18k Gold Zodiac Sign Necklace Fashion Accessories Hypoallergenic 1098n
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 300.67
#    - Coefficient of Variation: 21.943
#    - Seasonal Amplitude: 43.886
#    - Trend Slope: 8.4068
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Tala 18K Gold Kyle Inspired - Crystal Butterfly Necklace Exquisite packaging
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 149.29
#    - Coefficient of Variation: 32.583
#    - Seasonal Amplitude: 65.166
#    - Trend Slope: -3.4814
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Tala by Kyla Original Solar Eclipse Necklace 1 Pendant, 4 Looks Plus Gift Box
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 139.71
#    - Coefficient of Variation: 4.071
#    - Seasonal Amplitude: 8.143
#    - Trend Slope: -14.6019
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Trendy Aesthetic Simple Cute Fashion Pearl Necklace Choker For Men and Women
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 8.56
#    - Coefficient of Variation: 4.266
#    - Seasonal Amplitude: 8.532
#    - Trend Slope: -1.2567
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: Unisex Beadparadise Trendy Austhetic Simple Cute Fashion Pearl Necklace Choker For Men And Women
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 2053.64
#    - Coefficient of Variation: 3.491
#    - Seasonal Amplitude: 6.981
#    - Trend Slope: 290.0886
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: Wedding Pearl Jewelry Set Round Pearl Necklace Retro French Earrings Ring Simple Banquet Elegant
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 191.50
#    - Coefficient of Variation: 6.031
#    - Seasonal Amplitude: 12.063
#    - Trend Slope: 22.2973
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: YH Gold Plated Stainless Steel Black Oil Letter Pendant Necklace Accessories Unisex
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 100.71
#    - Coefficient of Variation: 5.917
#    - Seasonal Amplitude: 11.834
#    - Trend Slope: -2.5014
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: YOUJ Face Mask Strap Sunglasses Glasses Lanyard Holder Chain Necklace Pearl
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 65.84
#    - Coefficient of Variation: 4.748
#    - Seasonal Amplitude: 9.495
#    - Trend Slope: -8.5234
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [ JL♥️Stainless ]  stainless cross chain necklace
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 1934.47
#    - Coefficient of Variation: 0.691
#    - Seasonal Amplitude: 1.382
#    - Trend Slope: -143.1642
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [A&J] High Quality Stainless Steel Letter Pendant Necklace
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 645.78
#    - Coefficient of Variation: 1.195
#    - Seasonal Amplitude: 2.389
#    - Trend Slope: -53.2771
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [BM] COD✔ Necklace 18K Gold Plated Butterfly Pendant Delicate Everyday Necklace for Women P036
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 37.52
#    - Coefficient of Variation: 7.916
#    - Seasonal Amplitude: 15.832
#    - Trend Slope: -2.9384
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: [JL♥️Stainless] Stainless Gold 18# inches necklace
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 328.62
#    - Coefficient of Variation: 0.833
#    - Seasonal Amplitude: 1.666
#    - Trend Slope: -32.0257
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [Maii] RS007 Bangkok 18K RoseGold Crystal Diamonds Stones Necklace NR
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 69.78
#    - Coefficient of Variation: 4.071
#    - Seasonal Amplitude: 8.143
#    - Trend Slope: -7.2928
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [Maii] St Saint Benedict San Benito Mama Mary Faith Cross necklace NS FN016
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 61.67
#    - Coefficient of Variation: 10.561
#    - Seasonal Amplitude: 21.123
#    - Trend Slope: -1.9437
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [Tyaa] Jewelry box for set ring necklace earring 5*8*3cm
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 113.96
#    - Coefficient of Variation: 5.529
#    - Seasonal Amplitude: 11.058
#    - Trend Slope: -4.9849
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: [Value Choice] TBK 18k Gold Semicolon Butterfly Necklace for Women Fashion Accessories Jewelry Hypoallergenic 22n
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 0.00
#    - Coefficient of Variation: 0.000
#    - Seasonal Amplitude: 0.000
#    - Trend Slope: 0.0000
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: [ZOMI] Titanium Steel Cross Pendant Necklace For Women And Men
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 30.62
#    - Coefficient of Variation: 8.358
#    - Seasonal Amplitude: 16.715
#    - Trend Slope: -2.2745
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: []Hawaii Puka White Clam Chips Shell Necklace Natural Chips Seashell Choker Necklace For Women
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 180.82
#    - Coefficient of Variation: 4.071
#    - Seasonal Amplitude: 8.143
#    - Trend Slope: -18.8986
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: fashion jewelry Bangkok gold 24k gold plated necklace pendant for women
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 0.00
#    - Coefficient of Variation: 0.000
#    - Seasonal Amplitude: 0.000
#    - Trend Slope: 0.0000
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: ins simple double pearl necklace clavicle chain short necklace
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 113.47
#    - Coefficient of Variation: 3.624
#    - Seasonal Amplitude: 7.247
#    - Trend Slope: -6.6620
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: jewelry gift box shell desgin 3 sizes for set or necklace ,earrings, ring Plain pattern black sponge
#    Category: Stationery
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 196.66
#    - Coefficient of Variation: 2.864
#    - Seasonal Amplitude: 5.728
#    - Trend Slope: 21.4102
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: velvet High-end jewelry box necklace box 7x10cm
#    Category: Home & Living
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 621.16
#    - Coefficient of Variation: 15.972
#    - Seasonal Amplitude: 31.944
#    - Trend Slope: 23.5602
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 『27Pets』Adjustable Reflection Nylon Dog Collars Pet Collar with Bells Charm Necklace for Little Dogs Cat Collars Pet Supplies
#    Category: Pets
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 84.73
#    - Coefficient of Variation: 3.072
#    - Seasonal Amplitude: 6.144
#    - Trend Slope: -8.0562
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 【 GnG 】Jewelry 2n1 Different Design Necklace and Earrings Set For Fashion Accesories Stainless Steel
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 254.33
#    - Coefficient of Variation: 23.434
#    - Seasonal Amplitude: 46.868
#    - Trend Slope: -20.3141
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 【 GnG 】Jewelry Fashion Accesories Good Quality Initial Letter Necklace For Women Accesories
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 536.96
#    - Coefficient of Variation: 7.044
#    - Seasonal Amplitude: 14.089
#    - Trend Slope: -85.9927
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 【2/3/4mm】Charm Czech Glass Seed Beads DIY Bracelet Necklace For Jewelry Making Accessories
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 213.51
#    - Coefficient of Variation: 1.813
#    - Seasonal Amplitude: 3.625
#    - Trend Slope: -28.2928
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 【5.7K+ Sold】JYJIAYUJY 100% Sterling Silver S925 Long Necklace White Shell Pearl 6/8/10MM Minimalist Korean Fashion Style Casual Elegant Daily Trendy Hypoallergenic Fine Jewelry Gift-Ready AYN813-NEW
#    Category: Fashion Accessories
#    Demand Type: Low-demand
#
#    Metrics:
#    - Mean Monthly Sales: 54.04
#    - Coefficient of Variation: 8.891
#    - Seasonal Amplitude: 17.783
#    - Trend Slope: -0.9619
#
#    Interpretation:
#    - Low overall demand
#    - Consider SKU rationalization
# --------------------------------------------------------------------------------
#
# Product: 【In Stock】6 styles 18K Gold Chain Real S925 sterling silver Necklace Different Design/Length Gold plated pendant Chain Female Jewelry Gift
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 95.87
#    - Coefficient of Variation: 5.154
#    - Seasonal Amplitude: 10.309
#    - Trend Slope: -8.5811
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 【Stainless Not Fade】18K Gold Letter Necklace A-Z Pendant Snake Chain Choker Chain tala by kyla High Quality Letter Necklace Sea Shell Pendan Alphabet Personalize Stainle
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 978.20
#    - Coefficient of Variation: 1.907
#    - Seasonal Amplitude: 3.813
#    - Trend Slope: -53.3659
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: 【YH】Golden Stainless Steel Benedict San Benito Mama Mary Cross necklace Accessories(Free Box ）
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 69.64
#    - Coefficient of Variation: 5.616
#    - Seasonal Amplitude: 11.232
#    - Trend Slope: -4.2538
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: （random design/random color） Tribe Necklace Cat eye/Drago eye/Necklace/Unisex (1pcs price)
#    Category: Fashion Accessories
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 99.45
#    - Coefficient of Variation: 34.677
#    - Seasonal Amplitude: 69.355
#    - Trend Slope: -1.8031
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------
#
# Product: ［JL️♥️Stainless］paperclips stainless gold necklace/bracelet
#    Category: Baby & Kids Fashion
#    Demand Type: Seasonal-demand
#
#    Metrics:
#    - Mean Monthly Sales: 218.44
#    - Coefficient of Variation: 1.852
#    - Seasonal Amplitude: 3.705
#    - Trend Slope: -19.4802
#
#    Interpretation:
#    - Requires seasonal inventory planning
#    - Monitor peak periods closely
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Final Analysis Report
# Generate a comprehensive written analysis

# %%
# Cell 15: Final Analysis Report
"""
Generate a comprehensive written analysis
"""

print("=" * 80)
print("DEMAND SEGMENTATION ANALYSIS REPORT")
print("=" * 80)

total_products = len(metrics_df)
stable_count = len(metrics_df[metrics_df['demand_type'] == 'Stable-demand'])
seasonal_count = len(metrics_df[metrics_df['demand_type'] == 'Seasonal-demand'])
low_count = len(metrics_df[metrics_df['demand_type'] == 'Low-demand'])

report = f"""

1. EXECUTIVE SUMMARY
{'='*70}
This analysis classified {total_products} products into three demand segments:
- Stable-demand: {stable_count} products ({stable_count/total_products*100:.1f}%)
- Seasonal-demand: {seasonal_count} products ({seasonal_count/total_products*100:.1f}%)
- Low-demand: {low_count} products ({low_count/total_products*100:.1f}%)


2. CLASSIFICATION METHODOLOGY
{'='*70}
Products were classified using decomposition metrics from Section 2.2.2:

a) Coefficient of Variation (CV = std/mean)
   - Measures demand stability
   - Lower CV indicates more stable demand
   - Threshold: CV < {THRESHOLDS['cv_stable']} for stable

b) Seasonal Amplitude (from STL decomposition)
   - Measures strength of seasonal patterns
   - Higher amplitude indicates stronger seasonality
   - Threshold: Amplitude >= {THRESHOLDS['seasonal_strong']} for strong seasonality

c) Trend Slope (from decomposed trend component)
   - Measures long-term growth/decline
   - Extracted from seasonal decomposition analysis

NOTE: This classification builds upon the seasonal and trend decomposition
performed in Section 2.2.2, utilizing the identified seasonal components
to categorize products into actionable demand segments.


3. STABLE-DEMAND PRODUCTS
{'='*70}
Characteristics:
- Low variability (CV < {THRESHOLDS['cv_stable']})
- Weak seasonality (Amplitude < {THRESHOLDS['seasonal_weak']})
- Consistent month-to-month sales

Implications:
- Predictable inventory needs
- Lower safety stock requirements
- Efficient production scheduling
- Suitable for Just-In-Time inventory


4. SEASONAL-DEMAND PRODUCTS
{'='*70}
Characteristics:
- Strong seasonal patterns (Amplitude >= {THRESHOLDS['seasonal_strong']}) OR
- Moderate seasonality with variable demand

Observed Patterns:
"""

# Add seasonal pattern observations
seasonal_products = metrics_df[metrics_df['demand_type'] == 'Seasonal-demand']
top_seasonal = seasonal_products.sort_values('seasonal_amplitude', ascending=False).head(5)

report += "\nTop 5 Most Seasonal Products:\n"
for idx, row in top_seasonal.iterrows():
    report += f"  - {row['product'][:60]}... (Amplitude: {row['seasonal_amplitude']:.2f})\n"

report += f"""

Implications:
- Requires pre-season inventory buildup
- Higher safety stock during peak periods
- Need for flexible production capacity
- Promotional opportunities during peak seasons


5. LOW-DEMAND PRODUCTS
{'='*70}
Characteristics:
- Mean monthly sales < {THRESHOLDS['low_demand']:.2f}
- Often sporadic or infrequent purchases

Implications:
- Consider discontinuation or reduced SKU count
- Potential for consolidation with similar products
- Lower inventory priority
- Evaluate profitability vs. storage costs


6. CATEGORY INSIGHTS
{'='*70}
"""

# Add category breakdown
for category in metrics_df['category'].unique():
    cat_data = metrics_df[metrics_df['category'] == category]
    report += f"\n{category}:\n"
    for demand_type in ['Stable-demand', 'Seasonal-demand', 'Low-demand']:
        count = len(cat_data[cat_data['demand_type'] == demand_type])
        pct = count / len(cat_data) * 100 if len(cat_data) > 0 else 0
        report += f"  - {demand_type}: {count} ({pct:.1f}%)\n"

report += """

7. RECOMMENDATIONS
{'='*70}
Based on the classification:

For Stable-Demand Products:
  - Implement lean inventory practices
  - Use continuous replenishment models
  - Focus on cost optimization

For Seasonal-Demand Products:
  - Develop pre-season stocking strategies
  - Plan promotions around peak periods
  - Consider flexible sourcing options
  - Validate against Philippine seasonal events (rainy season, summer, holidays)

For Low-Demand Products:
  - Review SKU rationalization opportunities
  - Consider made-to-order fulfillment
  - Evaluate profitability and strategic value


8. NEXT STEPS
{'='*70}
1. Validate classifications with business stakeholders
2. Develop segment-specific forecasting models
3. Adjust inventory policies by demand type
4. Monitor and refine classifications quarterly
5. Integrate with supply chain planning systems

"""

print(report)

# Save report to file
with open('demand_classification_analysis_report.txt', 'w') as f:
    f.write(report)

print("\nAnalysis report saved to: demand_classification_analysis_report.txt")
# Out:
# ================================================================================
# DEMAND SEGMENTATION ANALYSIS REPORT
# ================================================================================
#
#
# 1. EXECUTIVE SUMMARY
# ======================================================================
# This analysis classified 25228 products into three demand segments:
# - Stable-demand: 12 products (0.0%)
# - Seasonal-demand: 18909 products (75.0%)
# - Low-demand: 6307 products (25.0%)
#
#
# 2. CLASSIFICATION METHODOLOGY
# ======================================================================
# Products were classified using decomposition metrics from Section 2.2.2:
#
# a) Coefficient of Variation (CV = std/mean)
#    - Measures demand stability
#    - Lower CV indicates more stable demand
#    - Threshold: CV < 0.3 for stable
#
# b) Seasonal Amplitude (from STL decomposition)
#    - Measures strength of seasonal patterns
#    - Higher amplitude indicates stronger seasonality
#    - Threshold: Amplitude >= 1.0 for strong seasonality
#
# c) Trend Slope (from decomposed trend component)
#    - Measures long-term growth/decline
#    - Extracted from seasonal decomposition analysis
#
# NOTE: This classification builds upon the seasonal and trend decomposition
# performed in Section 2.2.2, utilizing the identified seasonal components
# to categorize products into actionable demand segments.
#
#
# 3. STABLE-DEMAND PRODUCTS
# ======================================================================
# Characteristics:
# - Low variability (CV < 0.3)
# - Weak seasonality (Amplitude < 0.5)
# - Consistent month-to-month sales
#
# Implications:
# - Predictable inventory needs
# - Lower safety stock requirements
# - Efficient production scheduling
# - Suitable for Just-In-Time inventory
#
#
# 4. SEASONAL-DEMAND PRODUCTS
# ======================================================================
# Characteristics:
# - Strong seasonal patterns (Amplitude >= 1.0) OR
# - Moderate seasonality with variable demand
#
# Observed Patterns:
#
# Top 5 Most Seasonal Products:
#   - MICHAELA Chic Flap Card Holder Minimalist Slim Mini Coin Pur... (Amplitude: 300.00)
#   - Irregular Mirror Acrylic Mirror Wood Base Makeup Mirror Desk... (Amplitude: 300.00)
#   - Cute Felt Cartoon Bag – Mommy Gift Tote for Hundred Day Banq... (Amplitude: 300.00)
#   - Cavendish & Harvey Clear Mint Drops 200g... (Amplitude: 300.00)
#   - Black Suit Dust Cover Bag Formal Dress Storage Zip Bag Garme... (Amplitude: 300.00)
#
#
# Implications:
# - Requires pre-season inventory buildup
# - Higher safety stock during peak periods
# - Need for flexible production capacity
# - Promotional opportunities during peak seasons
#
#
# 5. LOW-DEMAND PRODUCTS
# ======================================================================
# Characteristics:
# - Mean monthly sales < 60.23
# - Often sporadic or infrequent purchases
#
# Implications:
# - Consider discontinuation or reduced SKU count
# - Potential for consolidation with similar products
# - Lower inventory priority
# - Evaluate profitability vs. storage costs
#
#
# 6. CATEGORY INSIGHTS
# ======================================================================
#
# Fashion Accessories:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 864 (74.2%)
#   - Low-demand: 300 (25.8%)
#
# Motorcycles:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 429 (82.0%)
#   - Low-demand: 94 (18.0%)
#
# Home & Living:
#   - Stable-demand: 1 (0.0%)
#   - Seasonal-demand: 4324 (76.9%)
#   - Low-demand: 1300 (23.1%)
#
# Sports & Outdoors:
#   - Stable-demand: 1 (0.1%)
#   - Seasonal-demand: 611 (75.1%)
#   - Low-demand: 202 (24.8%)
#
# Women Clothes:
#   - Stable-demand: 1 (0.1%)
#   - Seasonal-demand: 1403 (76.5%)
#   - Low-demand: 431 (23.5%)
#
# Beauty:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 2018 (76.7%)
#   - Low-demand: 614 (23.3%)
#
# Hobbies & Collections:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 317 (76.4%)
#   - Low-demand: 98 (23.6%)
#
# Home Appliances:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 506 (68.7%)
#   - Low-demand: 231 (31.3%)
#
# Pets:
#   - Stable-demand: 1 (0.1%)
#   - Seasonal-demand: 654 (79.3%)
#   - Low-demand: 170 (20.6%)
#
# Mobile & Gadgets:
#   - Stable-demand: 2 (0.1%)
#   - Seasonal-demand: 1083 (66.0%)
#   - Low-demand: 556 (33.9%)
#
# Baby & Kids Fashion:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 646 (70.4%)
#   - Low-demand: 272 (29.6%)
#
# Automobiles:
#   - Stable-demand: 1 (0.2%)
#   - Seasonal-demand: 309 (75.6%)
#   - Low-demand: 99 (24.2%)
#
# Stationery:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 1210 (76.4%)
#   - Low-demand: 374 (23.6%)
#
# Health:
#   - Stable-demand: 2 (0.2%)
#   - Seasonal-demand: 819 (74.5%)
#   - Low-demand: 279 (25.4%)
#
# Men Clothes:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 586 (77.5%)
#   - Low-demand: 170 (22.5%)
#
# Watches:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 70 (81.4%)
#   - Low-demand: 16 (18.6%)
#
# Men Bags:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 74 (76.3%)
#   - Low-demand: 23 (23.7%)
#
# Women Shoes:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 395 (77.9%)
#   - Low-demand: 112 (22.1%)
#
# Women Bags:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 382 (77.3%)
#   - Low-demand: 112 (22.7%)
#
# Mom & Baby:
#   - Stable-demand: 1 (0.1%)
#   - Seasonal-demand: 759 (79.7%)
#   - Low-demand: 192 (20.2%)
#
# Food & Beverages:
#   - Stable-demand: 2 (0.3%)
#   - Seasonal-demand: 492 (71.4%)
#   - Low-demand: 195 (28.3%)
#
# Travel & Luggage:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 186 (76.2%)
#   - Low-demand: 58 (23.8%)
#
# Audio:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 225 (64.1%)
#   - Low-demand: 126 (35.9%)
#
# Gaming & Consoles:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 25 (65.8%)
#   - Low-demand: 13 (34.2%)
#
# Computers & Accessories:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 204 (61.8%)
#   - Low-demand: 126 (38.2%)
#
# Books & Magazines:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 51 (67.1%)
#   - Low-demand: 25 (32.9%)
#
# Men Shoes:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 193 (77.2%)
#   - Low-demand: 57 (22.8%)
#
# Cameras & Drones:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 62 (50.8%)
#   - Low-demand: 60 (49.2%)
#
# Tickets, Vouchers & Services:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 8 (80.0%)
#   - Low-demand: 2 (20.0%)
#
# Muslim Fashion:
#   - Stable-demand: 0 (0.0%)
#   - Seasonal-demand: 4 (100.0%)
#   - Low-demand: 0 (0.0%)
#
#
# 7. RECOMMENDATIONS
# {'='*70}
# Based on the classification:
#
# For Stable-Demand Products:
#   - Implement lean inventory practices
#   - Use continuous replenishment models
#   - Focus on cost optimization
#
# For Seasonal-Demand Products:
#   - Develop pre-season stocking strategies
#   - Plan promotions around peak periods
#   - Consider flexible sourcing options
#   - Validate against Philippine seasonal events (rainy season, summer, holidays)
#
# For Low-Demand Products:
#   - Review SKU rationalization opportunities
#   - Consider made-to-order fulfillment
#   - Evaluate profitability and strategic value
#
#
# 8. NEXT STEPS
# {'='*70}
# 1. Validate classifications with business stakeholders
# 2. Develop segment-specific forecasting models
# 3. Adjust inventory policies by demand type
# 4. Monitor and refine classifications quarterly
# 5. Integrate with supply chain planning systems
#
#
#
# Analysis report saved to: demand_classification_analysis_report.txt

# %% [markdown]
# ### Export Classification Results
# Save all classification results to CSV files
# This is the final step after all analysis and validation is complete

# %%
# Cell 16: Export Classification Results
"""
Save all classification results to CSV files
This is the final step after all analysis and validation is complete
"""

print("=" * 80)
print("EXPORTING CLASSIFICATION RESULTS")
print("=" * 80)

# 1. Main classification table
classification_output = metrics_df[[
    'product', 'category', 'demand_type', 
    'mean_monthly_sales', 
    'coefficient_of_variation', 'seasonal_amplitude', 'trend_slope'
]].sort_values(['demand_type', 'mean_monthly_sales'], ascending=[True, False])

classification_output.to_csv('demand_classification_results.csv', index=False)
print("\n[1/4] Saved: demand_classification_results.csv")
print(f"      Contains: {len(classification_output)} products with classifications")

# 2. Thresholds table
thresholds_df.to_csv('classification_thresholds.csv', index=False)
print("\n[2/4] Saved: classification_thresholds.csv")
print(f"      Contains: Classification threshold definitions")

# 3. Summary statistics
summary_by_type = metrics_df.groupby('demand_type').agg({
    'product': 'count',
    'mean_monthly_sales': ['mean', 'median', 'std'],
    'coefficient_of_variation': ['mean', 'median'],
    'seasonal_amplitude': ['mean', 'median']
}).round(3)
summary_by_type.to_csv('classification_summary_statistics.csv')
print("\n[3/4] Saved: classification_summary_statistics.csv")
print(f"      Contains: Statistical summaries by demand type")

# 4. Category breakdown
category_breakdown = pd.crosstab(
    metrics_df['category'], 
    metrics_df['demand_type'],
    margins=True
)
category_breakdown.to_csv('classification_by_category.csv')
print("\n[4/4] Saved: classification_by_category.csv")
print(f"      Contains: Cross-tabulation of categories vs demand types")

print("\n" + "="*80)
print("ALL RESULTS EXPORTED SUCCESSFULLY")
print("="*80)

print("\nExported Files Summary:")
print("  1. demand_classification_results.csv - Main results with all products")
print("  2. classification_thresholds.csv - Threshold definitions used")
print("  3. classification_summary_statistics.csv - Statistics by demand type")
print("  4. classification_by_category.csv - Category breakdown")
print("  5. demand_classification_analysis_report.txt - Full written report")

print("\nThese files are ready for:")
print("  - Section 2.3: Inventory Optimization Insights")
print("  - Section 2.4: Predictive Model Development")
print("  - Final presentation and documentation")
# Out:
# ================================================================================
# EXPORTING CLASSIFICATION RESULTS
# ================================================================================
#
# [1/4] Saved: demand_classification_results.csv
#       Contains: 25228 products with classifications
#
# [2/4] Saved: classification_thresholds.csv
#       Contains: Classification threshold definitions
#
# [3/4] Saved: classification_summary_statistics.csv
#       Contains: Statistical summaries by demand type
#
# [4/4] Saved: classification_by_category.csv
#       Contains: Cross-tabulation of categories vs demand types
#
# ================================================================================
# ALL RESULTS EXPORTED SUCCESSFULLY
# ================================================================================
#
# Exported Files Summary:
#   1. demand_classification_results.csv - Main results with all products
#   2. classification_thresholds.csv - Threshold definitions used
#   3. classification_summary_statistics.csv - Statistics by demand type
#   4. classification_by_category.csv - Category breakdown
#   5. demand_classification_analysis_report.txt - Full written report
#
# These files are ready for:
#   - Section 2.3: Inventory Optimization Insights
#   - Section 2.4: Predictive Model Development
#   - Final presentation and documentation
